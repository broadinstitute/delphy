# %% [markdown]
# <a href="https://colab.research.google.com/github/broadinstitute/delphy/blob/main/tutorials/delphy_workflow_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="font-size: 2.5em; color: #2C3E50;">Running <a href="https://github.com/broadinstitute/delphy" target="_blank">Delphy</a> is as simple as 1, 2, 3 – Ebolavirus Example</h1>
#     <h2 style="font-size: 1.5em; color: #34495E;">Phylogenetic Tree Generation with Delphy on Ebolavirus Sequences</h2>
# </div>
#
# This notebook demonstrates how to generate a phylogenetic tree using [Delphy](https://github.com/broadinstitute/delphy) on viral sequences obtained from the [NCBI Virus Database](https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/). Optionally, you can also upload your own sequences to be included in the analysis.
#
# We will utilize the following tools:
# - [**gget**](https://pachterlab.github.io/gget/en/virus.html) to download viral sequences from the [NCBI Virus Database](https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/)
# - [**MAFFT**](https://mafft.cbrc.jp/alignment/server/index.html) for creating a Multiple-Sequence Alignment (MSA)
# - [**Delphy**](https://github.com/broadinstitute/delphy) to generate the phylogenetic tree
#
# In this example notebook, we already filled out the NCBI Virus filters and options below to download and analyze all **complete *Zaire ebolavirus* sequences from *Homo sapiens* hosts collected between January 01, 2014 and June 30, 2014**. All generated files will be saved in the **results/** folder, unless you specify a different output folder below.
#
# Simply **click `Runtime` -> `Run all`** at the top of this notebook.
#
# If you encounter any problems or questions while using this notebook, please [report them here](https://github.com/broadinstitute/delphy/issues).
#
# Total runtime: ~4 min
# ___
# ___

# %% [markdown]
# # 1. Apply filters to download sequences from [NCBI Virus](https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/)

# %%
#@title gget virus filtering options:
#@markdown Set any non-boolean filter to `None` to disable it.

def arg_str_to_bool(arg):
    if arg == "True":
        return True
    elif arg == "False":
        return False
    elif arg == "None" or arg == "":
        return None
    else:
        return arg

# -------------------------
# Virus query
# -------------------------
#@markdown ## **Virus**

virus = "Zaire ebolavirus"  #@param {type:"string"}
#@markdown  - Examples: 'Mammarenavirus lassaense' or 'coronaviridae' or 'NC_045512.2' or '142786' (Norovirus taxid).
virus = arg_str_to_bool(virus)

is_accession = False  #@param {type:"boolean"}
#@markdown  - Check this box if `virus` is given as an NCBI accession, space-separated list of accessions, or a path to a text file of accessions (one per line).
#@markdown  - For SARS-CoV-2 / Influenza A optimized downloads also check the corresponding box below (see `is_sars_cov2` / `is_alphainfluenza` below)
is_accession = arg_str_to_bool(is_accession)

download_all_accessions = False  #@param {type:"boolean"}
#@markdown  - ⚠️ Downloads ALL virus accessions (very large). When True, `virus` is ignored.
download_all_accessions = arg_str_to_bool(download_all_accessions)

# -------------------------
# Host filters
# -------------------------
#@markdown ## **Host**

host = "homo sapiens"  #@param {type:"string"}
#@markdown  - Host organism name OR NCBI Taxonomy ID (e.g., 'human', 'Aedes aegypti', '1335626').
#@markdown  - Input `None` to disable filtering by host.
host = arg_str_to_bool(host)

# -------------------------
# Sequence & gene filters
# -------------------------
#@markdown ## **Sequence & gene filters**

annotated = "None"  #@param ["True", "False", "None"]
#@markdown  - True: only annotated sequences. False: only NOT annotated. None: no filter.
annotated = arg_str_to_bool(annotated)

refseq_only = False  #@param {type:"boolean"}
#@markdown  - Limit search to RefSeq genomes only (curated).
refseq_only = arg_str_to_bool(refseq_only)

nuc_completeness = "complete"  #@param ["None", "complete", "partial"]
#@markdown  - Nucleotide completeness.
nuc_completeness = arg_str_to_bool(nuc_completeness)

min_seq_length = None  #@param {type:"raw"}
max_seq_length = None  #@param {type:"raw"}
min_seq_length = arg_str_to_bool(min_seq_length)
max_seq_length = arg_str_to_bool(max_seq_length)

max_ambiguous_chars = None  #@param {type:"raw"}
#@markdown  - Max number of ambiguous nucleotide characters (N's).
max_ambiguous_chars = arg_str_to_bool(max_ambiguous_chars)

min_gene_count = None  #@param {type:"raw"}
max_gene_count = None  #@param {type:"raw"}
min_gene_count = arg_str_to_bool(min_gene_count)
max_gene_count = arg_str_to_bool(max_gene_count)

min_protein_count = None  #@param {type:"raw"}
max_protein_count = None  #@param {type:"raw"}
min_protein_count = arg_str_to_bool(min_protein_count)
max_protein_count = arg_str_to_bool(max_protein_count)

min_mature_peptide_count = None  #@param {type:"raw"}
max_mature_peptide_count = None  #@param {type:"raw"}
min_mature_peptide_count = arg_str_to_bool(min_mature_peptide_count)
max_mature_peptide_count = arg_str_to_bool(max_mature_peptide_count)

has_proteins = None  #@param {type:"raw"}
#@markdown  - Require specific proteins/genes (e.g. "spike") or list (e.g. ["spike","ORF1ab"]).
has_proteins = arg_str_to_bool(has_proteins)

proteins_complete = False  #@param {type:"boolean"}
#@markdown  - Only include sequences where all annotated proteins are complete.
proteins_complete = arg_str_to_bool(proteins_complete)

# -------------------------
# Location & submitter filters
# -------------------------
#@markdown ## **Location & submitter filters**

geographic_location = None  #@param {type:"string"}
#@markdown  - Geographic location of sample collection (e.g. 'USA', 'Asia').
geographic_location = arg_str_to_bool(geographic_location)

submitter_country = None  #@param {type:"string"}
#@markdown  - Country of the sequence submitter.
submitter_country = arg_str_to_bool(submitter_country)

lab_passaged = "None"  #@param ["True", "False", "None"]
#@markdown  - True: only lab-passaged. False: exclude lab-passaged. None: no filter.
lab_passaged = arg_str_to_bool(lab_passaged)

# -------------------------
# Date filters
# -------------------------
#@markdown ## **Dates**
#@markdown All dates should be supplied in YYYY-MM-DD format.

min_collection_date = "2014-01-01"  #@param {type:"string"}
max_collection_date = "2014-06-30"  #@param {type:"string"}
min_release_date = "2014-01-01"  #@param {type:"string"}
max_release_date = "None"  #@param {type:"string"}

min_collection_date = arg_str_to_bool(min_collection_date)
max_collection_date = arg_str_to_bool(max_collection_date)
min_release_date = arg_str_to_bool(min_release_date)
max_release_date = arg_str_to_bool(max_release_date)

# -------------------------
# SARS-CoV-2 specific filters / optimizations
# -------------------------
#@markdown ## **SARS-CoV-2 / Influenza A optimizations**

lineage = None  #@param {type:"string"}
#@markdown  - SARS-CoV-2 lineage filter (e.g. 'B.1.1.7'). (Only meaningful for SARS-CoV-2 queries.)
lineage = arg_str_to_bool(lineage)

is_sars_cov2 = False  #@param {type:"boolean"}
#@markdown  - Use optimized cached downloads for SARS-CoV-2.
is_sars_cov2 = arg_str_to_bool(is_sars_cov2)

is_alphainfluenza = False  #@param {type:"boolean"}
#@markdown  - Use optimized cached downloads for Influenza A virus (Alphainfluenza).
is_alphainfluenza = arg_str_to_bool(is_alphainfluenza)

# -------------------------
# Optional GenBank metadata enrichment
# -------------------------
#@markdown ## **GenBank metadata enrichment**

genbank_metadata = False  #@param {type:"boolean"}
#@markdown  - Fetch additional detailed metadata from GenBank into a separate CSV/XML/CSV dumps.
genbank_metadata = arg_str_to_bool(genbank_metadata)

genbank_batch_size = 200  #@param {type:"integer"}
#@markdown  - Batch size for GenBank metadata API requests. Larger may be faster but can time out (default: 200).
genbank_batch_size = int(genbank_batch_size)

# -------------------------
# Workflow / output options
# -------------------------
#@markdown ## **Workflow / output options**

keep_temp = False  #@param {type:"boolean"}
#@markdown  - Keep intermediate temporary files.
keep_temp = arg_str_to_bool(keep_temp)

outfolder = "results"  #@param {type:"string"}
#@markdown  - Output folder path (defaults to current working directory if None).
outfolder = arg_str_to_bool(outfolder)

# %% [markdown]
# # 2. Optional: Upload a fasta file with your own sequences to add to the analysis
#   **1) Click on the folder icon on the left.
#   2) Upload your file(s) to the Google Colab server by dragging in your file(s) (or use rightclick -> Upload).
#   3) Specify the name of your file(s) here:**

# %%
#@title FASTA file containing additional sequences

fasta_file = None  #@param {type:"string"}
#@markdown  - Example: 'my_fasta_file.fa' or 'my_fasta_file.fasta'.

# %%
#@title Metadata

#@markdown **Option 1: The metadata is the same for all sequences in your FASTA file**
metadata = {'Collection Date': 'YYYY-MM-DD', 'Geo Location': 'South Korea'}  #@param {type:"raw"}
#@markdown - The 'Collection Date' field is required. Optional: you can add as many additional columns as you wish, e.g. 'Geo Location': 'South Korea'.
#@markdown - NOTE: Use NCBI column names where applicable (see https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/virus for example column names)

#@markdown **Option 2: Input a CSV file with metadata for each sequence**
metadata_csv = None  #@param {type:"string"}
#@markdown  - Example: 'my_metadata.csv'. This file must include at least an 'Accession' and 'Collection Date' column.
#@markdown  - NOTE: Make sure the IDs in the "Accession" column match the IDs of the sequences in the provided FASTA file
#@markdown  - NOTE: Use NCBI column names where applicable (see https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/virus for example column names)

# Convert empty strings to None
fasta_file = arg_str_to_bool(fasta_file)
metadata_csv = arg_str_to_bool(metadata_csv)

# %% [markdown]
# # 3. Optional: Specify Delphy arguments

# %%
#@title Delphy options:
mutation_rate = None  #@param {type:"raw"}
#@markdown  - Virus mutation rate (mutations per site per year), e.g. 0.01. If set to `None`, the mutation rate will be estimated from the generated tree.

delphy_steps = None  #@param {type:"raw"}
#@markdown  - Number of steps to run in the Delphy algorithm (default: 500,000 * number of sequences).

delphy_samples = 200 #@param {type:"integer"}
#@markdown  - Number of logging and tree updates (will log every `delphy_steps/delphy_samples` step).

delphy_release = "1.2.2"  #@param {type:"string"}
#@markdown  - Delphy version to use (see https://github.com/broadinstitute/delphy/releases).

#@title Delphy options:
threads = 2  #@param {type:"integer"}
#@markdown  - Number of threads to use for the MSA (Mafft) and phylogenetic tree (Delphy) generation.

# %% [markdown]
# # All done! Select `Runtime` at the top of this notebook, then click `Run all` and lean back...
# A completion message will be displayed below once the notebook has been successfully executed.
# **💡 Tip: Click on the folder icon 📁 on the left to view/download the files that are being generated.**
#
# <br>
#
# ____
# ____
# ____
# ____

# %%
# %%time

#@title # Generating the phylogenetic tree...

from IPython.display import display, HTML
from pathlib import Path
import subprocess
import sys
import shutil
import glob
import pandas as pd
import re
import os
from datetime import datetime

# ---------- Small UI helpers ----------
def log_message(text):
    display(HTML(f"<h3 style='color:green;margin:6px 0'>{text}</h3>"))

def log_message_sub(text):
    display(HTML(f"<p style='color:black; font-weight:normal; margin:4px 0;'>{text}</p>"))

def log_message_error(text):
    display(HTML(f"<h3 style='color:red;margin:6px 0'>{text}</h3>"))

def run_checked(cmd, **kwargs):
    """Run subprocess.run with sensible defaults and return CompletedProcess or raise."""
    default = dict(check=True, text=True, capture_output=True)
    default.update(kwargs)
    return subprocess.run(cmd, **default)

# ---------- Validate / create outfolder ----------
outfolder = Path(outfolder) if 'outfolder' in globals() else Path("delphy_out")
outfolder.mkdir(parents=True, exist_ok=True)

# ---------- 1) Install Python requirements (gget) ----------
log_message("1/5 Installing Python dependencies (gget)...")
try:
    # !pip install --upgrade -q gget biopython
    import gget
    from Bio import SeqIO
    log_message_sub("Python dependencies installed.")
except Exception as e:
    log_message_error("Failed to install Python dependencies (gget).")
    print(e)
    raise

# ---------- 2) Download sequences from NCBI using gget ----------
log_message("2/5 Downloading viral sequences from NCBI (gget.virus)... This may take a few minutes.")
try:
    # The original code used many parameters assumed present in the notebook; call gget.virus with locals()
    # Build kwargs only from variables that exist in globals() and are not None.
    possible_kwargs = [
        "virus","is_accession","download_all_accessions","host",
        "nuc_completeness","min_seq_length","max_seq_length",
        "min_gene_count","max_gene_count","min_mature_peptide_count","max_mature_peptide_count",
        "min_protein_count","max_protein_count","max_ambiguous_chars","has_proteins","proteins_complete","annotated","refseq_only",
        "geographic_location","submitter_country","lab_passaged",
        "min_collection_date","max_collection_date","min_release_date","max_release_date",
        "lineage","is_sars_cov2","is_alphainfluenza",
        "genbank_metadata","genbank_batch_size","keep_temp","outfolder"
    ]
    gget_kwargs = {k: globals()[k] for k in possible_kwargs if k in globals() and globals()[k] is not None}
    # Ensure outfolder is string path for gget
    if "outfolder" not in gget_kwargs:
        gget_kwargs["outfolder"] = str(outfolder)
    else:
        gget_kwargs["outfolder"] = str(Path(gget_kwargs["outfolder"]))
    # Call gget.virus
    gget.virus(**gget_kwargs)

    # Find the newest fasta and metadata file in outfolder
    fasta_candidates = list(outfolder.glob("*.fasta")) + list(outfolder.glob("*.fa"))
    if not fasta_candidates:
        raise FileNotFoundError(f"No fasta files were created in {outfolder}")
    ncbi_fasta_file = max(fasta_candidates, key=lambda p: p.stat().st_mtime)

    metadata_candidates = list(outfolder.glob("*.csv")) + list(outfolder.glob("*.jsonl")) + list(outfolder.glob("*.tsv"))
    if not metadata_candidates:
        raise FileNotFoundError(f"No metadata files were created in {outfolder}")
    ncbi_metadata = max(metadata_candidates, key=lambda p: p.stat().st_mtime)

    log_message_sub(f"Download complete. FASTA: {ncbi_fasta_file.name}  Metadata: {ncbi_metadata.name}")
except Exception as e:
    log_message_error("Error while downloading sequences from NCBI.")
    print(e)
    raise

# ---------- 2b) If user provided FASTA/metadata, merge them ----------
input_fasta_file = Path(ncbi_fasta_file)
metadata_file = Path(ncbi_metadata)

if 'fasta_file' in globals() and fasta_file:
    log_message_sub("Merging user-provided FASTA with NCBI FASTA...")
    try:
        combined_fasta_file = outfolder / f"{'_'.join(str(virus).split())}_sequences_combined.fasta"
        with open(combined_fasta_file, "wb") as outfh:
            for src in [ncbi_fasta_file, Path(fasta_file)]:
                with open(src, "rb") as fh:
                    shutil.copyfileobj(fh, outfh)
        input_fasta_file = combined_fasta_file

        # Combine metadata
        combined_metadata_file = outfolder / f"{'_'.join(str(virus).split())}_metadata_combined.csv"
        ncbi_df = pd.read_csv(ncbi_metadata)

        if 'metadata_csv' in globals() and metadata_csv:
            user_meta_df = pd.read_csv(metadata_csv)
            comb_meta_df = pd.concat([ncbi_df, user_meta_df], ignore_index=True, sort=False)
            comb_meta_df.to_csv(combined_metadata_file, index=False)
            metadata_file = combined_metadata_file
        else:
            # If user provided `metadata` mapping and FASTA only
            headers = [record.id.split()[0] for record in SeqIO.parse(fasta_file, "fasta")]
            user_meta_df = pd.DataFrame({"accession": headers})
            if 'metadata' in globals() and isinstance(metadata, dict):
                for k, v in metadata.items():
                    # Broadcast scalar values or accept list-like
                    if hasattr(v, "__len__") and not isinstance(v, str) and len(v) == len(headers):
                        user_meta_df[k] = v
                    else:
                        user_meta_df[k] = [v] * len(headers)
            comb_meta_df = pd.concat([ncbi_df, user_meta_df], ignore_index=True, sort=False)
            comb_meta_df.to_csv(combined_metadata_file, index=False)
            metadata_file = combined_metadata_file

        log_message_sub(f"Merging complete. Combined FASTA: {combined_fasta_file.name}  Combined metadata: {combined_metadata_file.name}")
    except Exception as e:
        log_message_error("Error while merging user-provided data.")
        print(e)
        raise

# ---------- 3) Multiple Sequence Alignment (MSA) using MAFFT (Colab-friendly, --parttree for >10k) ----------
log_message("3/5 Multiple Sequence Alignment (MAFFT). This may take time depending on # sequences and threads.")

aligned_fasta_file = outfolder / f"{'_'.join(str(virus).split())}_aligned.afa"

def count_fasta_records(path: Path):
    return sum(1 for _ in SeqIO.parse(str(path), "fasta"))

# 1) Check for mafft binary
def mafft_is_available():
    return bool(shutil.which("mafft"))

# 2) If not available, attempt the same .deb download + dpkg approach you had for Colab
if not mafft_is_available():
    try:
        log_message_sub("MAFFT not found — attempting to download & install MAFFT .deb (Colab-compatible).")
        deb_path = outfolder / "mafft_7.526-1_amd64.deb"
        # download
        subprocess.run(["wget", "-q", "-O", str(deb_path),
                        "https://mafft.cbrc.jp/alignment/software/mafft_7.526-1_amd64.deb"],
                       check=True, text=True)
        # install
        subprocess.run(["dpkg", "-i", str(deb_path)], check=True, text=True)
        # If dpkg left missing deps, try apt-get -f install
        subprocess.run(["apt-get", "-y", "install", "-f"], check=True, text=True)
        if mafft_is_available():
            log_message_sub("MAFFT installed successfully.")
        else:
            log_message_error("MAFFT was not found after .deb install. Please install MAFFT manually in the Colab environment.")
            raise FileNotFoundError("mafft binary not found after .deb install")
    except subprocess.CalledProcessError as e:
        log_message_error("An error occurred while attempting to install MAFFT via .deb.")
        # print stderr/stdout if available
        try:
            print(e.stderr or e.stdout)
        except Exception:
            print(e)
        raise

# 3) Prepare MAFFT command, adding --parttree for large datasets
num_seqs = count_fasta_records(input_fasta_file)
threads = int(threads) if 'threads' in globals() and threads else 1

# Build command; place --parttree right after "mafft" (recommended)
if num_seqs > 10_000:
    log_message_sub(f"Detected {num_seqs:,} sequences — using MAFFT with --parttree optimized for large datasets.")
    mafft_cmd = ["mafft", "--parttree", "--auto", "--thread", str(threads), str(input_fasta_file)]
else:
    log_message_sub(f"Detected {num_seqs:,} sequences — using MAFFT standard --auto mode.")
    mafft_cmd = ["mafft", "--auto", "--thread", str(threads), str(input_fasta_file)]

# 4) Run MAFFT and write alignment directly to file (no capture_output conflict)
try:
    log_message_sub(f"Running: {' '.join(mafft_cmd[:6])} ... (command truncated in log)")
    with open(aligned_fasta_file, "w") as outfh:
        # IMPORTANT: do NOT use capture_output=True here; provide stdout=outfh instead
        subprocess.run(mafft_cmd, stdout=outfh, stderr=subprocess.PIPE, check=True, text=True)
    log_message_sub(f"MSA complete and saved to: {aligned_fasta_file.name}")
except subprocess.CalledProcessError as e:
    log_message_error("Error while running MAFFT for MSA. See stderr below:")
    stderr = e.stderr.decode() if isinstance(e.stderr, (bytes, bytearray)) else e.stderr
    print(stderr)
    raise
except Exception as e:
    log_message_error("Unexpected error while running MAFFT.")
    print(e)
    raise

# ---------- 4) Reformat FASTA headers to match Delphy format (accession|YYYY-MM-DD) ----------
log_message("4/5 Reformatting FASTA headers to 'accession|YYYY-MM-DD' (skipping entries without valid collection dates).")

def extract_and_format_date(date_string: str, accept_uncertain_dates: bool = False):
    """Return YYYY-MM-DD, YYYY-MM, or YYYY depending on accept_uncertain_dates. Return None if unrecognized."""
    if pd.isna(date_string):
        return None
    date_string = str(date_string).strip()
    # Normalize separators to '-'
    date_string = re.sub(r"[/.]", "-", date_string)
    # Try parsing strict YYYY-MM-DD
    full_date_re = re.compile(r"^\d{4}-\d{1,2}-\d{1,2}$")
    year_month_re = re.compile(r"^\d{4}-\d{1,2}$")
    year_re = re.compile(r"^\d{4}$")
    if full_date_re.match(date_string):
        return date_string
    if year_month_re.match(date_string):
        return date_string if accept_uncertain_dates else "EXCLUDED"
    if year_re.match(date_string):
        return date_string if accept_uncertain_dates else "EXCLUDED"
    # Try to parse more flexible formats (e.g., 'Jan 2 2020' or '2 Jan 2020') using datetime
    for fmt in ("%Y-%m-%d", "%d-%b-%Y", "%d %b %Y", "%b %d %Y", "%Y/%m/%d"):
        try:
            dt = datetime.strptime(date_string, fmt)
            return dt.strftime("%Y-%m-%d")
        except Exception:
            continue
    return None

def find_date_columns(df: pd.DataFrame):
    """Heuristic to find which column likely contains collection date and accession."""
    date_cols = [c for c in df.columns if re.search(r"date|collection|collected", c, flags=re.I)]
    acc_cols = [c for c in df.columns if re.search(r"acc(?:ession)?|id|seq_id", c, flags=re.I)]
    # Fallback sensible names
    if not date_cols and "Collection Date" in df.columns:
        date_cols = ["Collection Date"]
    if not acc_cols and "accession" in df.columns:
        acc_cols = ["accession"]
    # Return first hits or None
    return (date_cols[0] if date_cols else None, acc_cols[0] if acc_cols else None)

def update_fasta_headers(fasta_in: Path, csv_in: Path, fasta_out: Path, accept_uncertain_dates: bool = False):
    """Rewrite fasta headers to 'accession|date' using CSV metadata. Exclude entries without valid date."""
    df = pd.read_csv(csv_in, dtype=str)
    date_col, acc_col = find_date_columns(df)
    if date_col is None or acc_col is None:
        raise ValueError(f"Could not find accession/date columns in {csv_in}. Found columns: {list(df.columns)}")
    accession_to_date = pd.Series(df[date_col].values, index=df[acc_col]).to_dict()

    included = 0
    excluded = 0
    unrecognized = 0

    with open(fasta_in) as fh_in, open(fasta_out, "w") as fh_out:
        for record in SeqIO.parse(fh_in, "fasta"):
            original_accession = record.id.split()[0]
            date_val = accession_to_date.get(original_accession) or accession_to_date.get(original_accession.split("|")[0])
            formatted = extract_and_format_date(date_val, accept_uncertain_dates=accept_uncertain_dates)
            if formatted == "EXCLUDED":
                excluded += 1
                continue
            if formatted is None:
                unrecognized += 1
                continue
            # Set header and remove description
            record.id = f"{original_accession}|{formatted}"
            record.description = ""
            SeqIO.write(record, fh_out, "fasta")
            included += 1

    return {"included": included, "excluded": excluded, "unrecognized": unrecognized}

aligned_fasta_file_clean = outfolder / f"{'_'.join(str(virus).split())}_aligned_headers_adjusted.afa"
try:
    accept_uncertain_dates = bool(globals().get("accept_uncertain_dates", False))
    stats = update_fasta_headers(aligned_fasta_file, metadata_file, aligned_fasta_file_clean, accept_uncertain_dates=accept_uncertain_dates)
    log_message_sub(f"Reformatting complete. Included {stats['included']} sequences; excluded (incomplete dates) {stats['excluded']}; unrecognized {stats['unrecognized']}")
except Exception as e:
    log_message_error("Error while reformatting FASTA headers.")
    print(e)
    raise

# ---------- 5) Run Delphy ----------
log_message("5/5 Preparing and running Delphy. This step can be long depending on steps/samples/sequence count.")

def count_fasta_records(path: Path):
    return sum(1 for _ in SeqIO.parse(str(path), "fasta"))

num_seqs = count_fasta_records(aligned_fasta_file_clean)
if num_seqs == 0:
    raise RuntimeError(f"No sequences found in {aligned_fasta_file_clean}")

# sensible defaults for delphy params if not provided
delphy_steps = globals().get("delphy_steps")
delphy_samples = globals().get("delphy_samples", 100)
if delphy_steps is None:
    delphy_steps = int(500_000 * max(1, num_seqs))

log_every = int(delphy_steps / delphy_samples) if delphy_samples else max(1, delphy_steps // 100)
tree_every = log_every
delphy_snapshot_every = log_every

# Download delphy if not present
delphy_bin = (Path.cwd() / "delphy").resolve()
if not delphy_bin.exists():
    delphy_release = globals().get("delphy_release", "1.2.2")  # user may override
    tarball = outfolder / "delphy_release.tar.gz"
    try:
        download_url = f"https://github.com/broadinstitute/delphy/releases/download/{delphy_release}/delphy-linux-x86_64-ubuntu22.tar.gz"
        log_message_sub(f"Downloading Delphy release {delphy_release}.")
        run_checked(["wget", "-q", "-O", str(tarball), download_url])
        run_checked(["tar", "-xzf", str(tarball)], check=True)
        # Try to find delphy binary in extracted files
        found = list(Path(".").glob("**/delphy"))
        if found:
            found[0].chmod(found[0].stat().st_mode | 0o111)
            shutil.copy(found[0], delphy_bin)
            log_message_sub("Delphy binary obtained.")
        else:
            log_message_error("Delphy binary not found inside downloaded archive.")
            raise FileNotFoundError("delphy binary not found")
    except Exception as e:
        log_message_error("Failed to download/extract Delphy. Please ensure `delphy` binary is available in the working directory.")
        print(e)
        raise

# Build Delphy command
beast_log_out = outfolder / f"{'_'.join(str(virus).split())}_delphy_beast.log"
delphy_beast_tree_out = outfolder / f"{'_'.join(str(virus).split())}_delphy_beast.trees"
dphy_out = outfolder / f"{'_'.join(str(virus).split())}_delphy_out.dphy"

mutation_rate = globals().get("mutation_rate", None)
threads = int(globals().get("threads", 1))
cmd = [
    str(delphy_bin),
    "--v0-log-every", str(log_every),
    "--v0-tree-every", str(tree_every),
    "--v0-delphy-snapshot-every", str(delphy_snapshot_every),
    "--v0-threads", str(threads),
    "--v0-steps", str(delphy_steps),
    "--v0-in-fasta", str(aligned_fasta_file_clean),
    "--v0-out-log-file", str(beast_log_out),
    "--v0-out-trees-file", str(delphy_beast_tree_out),
    "--v0-out-delphy-file", str(dphy_out),
]
if mutation_rate:
    cmd = [str(delphy_bin), "--v0-fix-mutation-rate", "--v0-init-mutation-rate", str(mutation_rate)] + cmd[1:]

log_message_sub(f"Running Delphy with command: {' '.join(cmd[:8])} ... (truncated)")

try:
    # Run delphy and stream output to notebook
    proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)
    for line in proc.stdout:
        # print lines incrementally so the notebook shows progress
        print(line, end="")
    ret = proc.wait()
    if ret != 0:
        raise subprocess.CalledProcessError(ret, cmd)
    # Success
    display(HTML("""
    <h2 style='color:green'>All done! 🎉</h2>
    <p>Files generated in this notebook are in the left-hand file browser (or in the folder you set as <code>outfolder</code>).</p>
    <ul>
      <li>Aligned FASTA: <code>{}</code></li>
      <li>Delphy output (.dphy): <code>{}</code></li>
      <li>Delphy log (.log): <code>{}</code></li>
      <li>Delphy trees (.trees): <code>{}</code></li>
    </ul>
    <p>We recommend downloading the <code>.afa</code>, <code>.dphy</code>, and <code>metadata.csv</code> files. To visualize .dphy files online, try <a href='https://delphy.fathom.info/' target='_blank'>delphy.fathom.info</a>.</p>
    """.format(aligned_fasta_file_clean.name, dphy_out.name, beast_log_out.name, delphy_beast_tree_out.name)))
except subprocess.CalledProcessError as e:
    log_message_error("An error occurred while running Delphy. See captured output above for details.")
    print(e)
    raise
except Exception as e:
    log_message_error("Unexpected error while running Delphy.")
    print(e)
    raise
# Out:
# <h3 style='color:green;margin:6px 0'>1/5 Installing Python dependencies (gget)...</h3>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Python dependencies installed.</p>
# <h3 style='color:green;margin:6px 0'>2/5 Downloading viral sequences from NCBI (gget.virus)... This may take a few minutes.</h3>
# INFO:gget.utils:Starting virus data retrieval process...
# INFO:gget.utils:Query parameters: virus='Zaire ebolavirus', is_accession=False, outfolder='results'
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 1: VALIDATING INPUT ARGUMENTS AND OUTPUT DIRECTORY SETUP...
# INFO:gget.utils:============================================================
# INFO:gget.utils:Input validation completed successfully
# INFO:gget.utils:Using specified output folder: results
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 2: CHECKING FOR SARS-CoV-2 AND INFLUENZA A QUERIES TO APPLY OPTIMIZED CACHED PATHWAY
# INFO:gget.utils:============================================================
# INFO:gget.utils: Skipping this step. No SARS-CoV-2 query detected.
# INFO:gget.utils: Skipping this step. No Alphainfluenza query detected.
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 3: Fetching virus metadata from NCBI API
# INFO:gget.utils:============================================================
# INFO:gget.utils:Streaming API metadata to temporary file: results/tmp_20260213_002733_744688/gget_metadata_20260213_002733_744688.jsonl
# INFO:gget.utils:Successfully retrieved 416 virus records from NCBI API across 1 pages
# INFO:gget.utils:Temporary metadata file size: 1.23 MB
# INFO:gget.utils:Processed 416 metadata records, skipped 0 records without accessions
# INFO:gget.utils:✅ Saved API metadata JSONL: results/Zaire_ebolavirus_api_metadata.jsonl
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 4: Applying metadata-only filters
# INFO:gget.utils:============================================================
# INFO:gget.utils:Starting metadata-only filtering process...
# INFO:gget.utils:Processing 416 metadata records...
# INFO:gget.utils:✅ Metadata-only filtering process complete.
# INFO:gget.utils:=================================
# INFO:gget.utils:Metadata-only filtering complete:
# INFO:gget.utils:  Total metadata records: 416
# INFO:gget.utils:  Records passing filters: 180
# INFO:gget.utils:Filter statistics (records excluded):
# INFO:gget.utils:  collection_date: 236 records
# INFO:gget.utils:✅ Saved filtered metadata JSONL: results/Zaire_ebolavirus_metadata.jsonl
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 5: Downloading sequences for filtered accessions
# INFO:gget.utils:============================================================
# INFO:gget.utils:Downloading sequences for 180 accessions using E-utilities API
# INFO:gget.utils:Initiating E-utilities request for 180 accessions
# INFO:gget.utils:Received 180 sequences from E-utilities
# INFO:gget.utils:Successfully saved sequences to: results/tmp_20260213_002733_744688/virus_sequences_20260213_002733_744688.fasta (3.31 MB)
# INFO:gget.utils:Downloaded FASTA file: results/tmp_20260213_002733_744688/virus_sequences_20260213_002733_744688.fasta (3.31 MB)
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 6: Applying sequence-dependent filters and saving results
# INFO:gget.utils:============================================================
# INFO:gget.utils:No sequence-dependent filters specified, skipping this step.
# INFO:gget.utils:All 180 downloaded sequences will be saved
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 7: Saving final output files
# INFO:gget.utils:============================================================
# INFO:gget.utils:Saving 180 filtered sequences and their metadata...
# INFO:gget.utils:✅ FASTA file saved: results/Zaire_ebolavirus_sequences.fasta (3.31 MB)
# INFO:gget.utils:✅ JSONL metadata file saved: results/Zaire_ebolavirus_metadata.jsonl (0.43 MB)
# INFO:gget.utils:Preparing metadata for CSV output...
# INFO:gget.utils:Processing metadata records...
# INFO:gget.utils:Creating DataFrame with 180 rows and 39 columns
# INFO:gget.utils:Successfully saved metadata CSV to: results/Zaire_ebolavirus_metadata.csv
# INFO:gget.utils:✅ CSV metadata file saved: results/Zaire_ebolavirus_metadata.csv (0.37 MB)
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 8: Fetching detailed GenBank metadata
# INFO:gget.utils:============================================================
# INFO:gget.utils:Skipping this step since GenBank metadata retrieval was not requested.
# INFO:gget.utils:============================================================
# INFO:gget.utils:PROCESS COMPLETED SUCCESSFULLY
# INFO:gget.utils:============================================================
# INFO:gget.utils:Results summary:
# INFO:gget.utils:  Total sequences (API metadata): 416
# INFO:gget.utils:  After metadata-only filtering: 180
# INFO:gget.utils:  After all filters (final): 180
# INFO:gget.utils:
# INFO:gget.utils:Output files saved to: results
# INFO:gget.utils:  📄 Sequences (FASTA): Zaire_ebolavirus_sequences.fasta
# INFO:gget.utils:  📊 Metadata (CSV):    Zaire_ebolavirus_metadata.csv
# INFO:gget.utils:  🔧 Metadata (JSONL):  Zaire_ebolavirus_metadata.jsonl
# INFO:gget.utils:============================================================
# INFO:gget.utils:============================================================
# INFO:gget.utils:✅ Command summary saved: results/command_summary.txt
# INFO:gget.utils:NCBI virus data retrieval process completed.
# <p style='color:black; font-weight:normal; margin:4px 0;'>Download complete. FASTA: Zaire_ebolavirus_sequences.fasta  Metadata: Zaire_ebolavirus_metadata.csv</p>
# <h3 style='color:green;margin:6px 0'>3/5 Multiple Sequence Alignment (MAFFT). This may take time depending on # sequences and threads.</h3>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Detected 180 sequences — using MAFFT standard --auto mode.</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Running: mafft --auto --thread 2 results/Zaire_ebolavirus_sequences.fasta ... (command truncated in log)</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>MSA complete and saved to: Zaire_ebolavirus_aligned.afa</p>
# <h3 style='color:green;margin:6px 0'>4/5 Reformatting FASTA headers to 'accession|YYYY-MM-DD' (skipping entries without valid collection dates).</h3>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Reformatting complete. Included 180 sequences; excluded (incomplete dates) 0; unrecognized 0</p>
# <h3 style='color:green;margin:6px 0'>5/5 Preparing and running Delphy. This step can be long depending on steps/samples/sequence count.</h3>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Running Delphy with command: /content/delphy --v0-log-every 450000 --v0-tree-every 450000 --v0-delphy-snapshot-every 450000 --v0-threads ... (truncated)</p>
# # Seed: 2733193560
# Reading fasta file results/Zaire_ebolavirus_aligned_headers_adjusted.afa
# - read 1 sequences so far (19321 of 3473640 bytes = 0.6%)
# - read 2 sequences so far (38619 of 3473640 bytes = 1.1%)
# - read 3 sequences so far (57917 of 3473640 bytes = 1.7%)
# - read 4 sequences so far (77215 of 3473640 bytes = 2.2%)
# - read 5 sequences so far (96513 of 3473640 bytes = 2.8%)
# - read 6 sequences so far (115811 of 3473640 bytes = 3.3%)
# - read 7 sequences so far (135109 of 3473640 bytes = 3.9%)
# - read 8 sequences so far (154407 of 3473640 bytes = 4.4%)
# - read 9 sequences so far (173705 of 3473640 bytes = 5.0%)
# - read 10 sequences so far (193003 of 3473640 bytes = 5.6%)
# - read 11 sequences so far (212301 of 3473640 bytes = 6.1%)
# - read 12 sequences so far (231599 of 3473640 bytes = 6.7%)
# - read 13 sequences so far (250897 of 3473640 bytes = 7.2%)
# - read 14 sequences so far (270195 of 3473640 bytes = 7.8%)
# - read 15 sequences so far (289493 of 3473640 bytes = 8.3%)
# - read 16 sequences so far (308791 of 3473640 bytes = 8.9%)
# - read 17 sequences so far (328089 of 3473640 bytes = 9.4%)
# - read 18 sequences so far (347387 of 3473640 bytes = 10.0%)
# - read 19 sequences so far (366685 of 3473640 bytes = 10.6%)
# - read 20 sequences so far (385983 of 3473640 bytes = 11.1%)
# - read 21 sequences so far (405281 of 3473640 bytes = 11.7%)
# - read 22 sequences so far (424579 of 3473640 bytes = 12.2%)
# - read 23 sequences so far (443877 of 3473640 bytes = 12.8%)
# - read 24 sequences so far (463175 of 3473640 bytes = 13.3%)
# - read 25 sequences so far (482473 of 3473640 bytes = 13.9%)
# - read 26 sequences so far (501771 of 3473640 bytes = 14.4%)
# - read 27 sequences so far (521069 of 3473640 bytes = 15.0%)
# - read 28 sequences so far (540367 of 3473640 bytes = 15.6%)
# - read 29 sequences so far (559665 of 3473640 bytes = 16.1%)
# - read 30 sequences so far (578963 of 3473640 bytes = 16.7%)
# - read 31 sequences so far (598261 of 3473640 bytes = 17.2%)
# - read 32 sequences so far (617559 of 3473640 bytes = 17.8%)
# - read 33 sequences so far (636857 of 3473640 bytes = 18.3%)
# - read 34 sequences so far (656155 of 3473640 bytes = 18.9%)
# - read 35 sequences so far (675453 of 3473640 bytes = 19.4%)
# - read 36 sequences so far (694751 of 3473640 bytes = 20.0%)
# - read 37 sequences so far (714049 of 3473640 bytes = 20.6%)
# - read 38 sequences so far (733347 of 3473640 bytes = 21.1%)
# - read 39 sequences so far (752645 of 3473640 bytes = 21.7%)
# - read 40 sequences so far (771943 of 3473640 bytes = 22.2%)
# - read 41 sequences so far (791241 of 3473640 bytes = 22.8%)
# - read 42 sequences so far (810539 of 3473640 bytes = 23.3%)
# - read 43 sequences so far (829837 of 3473640 bytes = 23.9%)
# - read 44 sequences so far (849135 of 3473640 bytes = 24.4%)
# - read 45 sequences so far (868433 of 3473640 bytes = 25.0%)
# - read 46 sequences so far (887731 of 3473640 bytes = 25.6%)
# - read 47 sequences so far (907029 of 3473640 bytes = 26.1%)
# - read 48 sequences so far (926327 of 3473640 bytes = 26.7%)
# - read 49 sequences so far (945625 of 3473640 bytes = 27.2%)
# - read 50 sequences so far (964923 of 3473640 bytes = 27.8%)
# - read 51 sequences so far (984221 of 3473640 bytes = 28.3%)
# - read 52 sequences so far (1003519 of 3473640 bytes = 28.9%)
# - read 53 sequences so far (1022817 of 3473640 bytes = 29.4%)
# - read 54 sequences so far (1042115 of 3473640 bytes = 30.0%)
# - read 55 sequences so far (1061413 of 3473640 bytes = 30.6%)
# - read 56 sequences so far (1080711 of 3473640 bytes = 31.1%)
# - read 57 sequences so far (1100009 of 3473640 bytes = 31.7%)
# - read 58 sequences so far (1119307 of 3473640 bytes = 32.2%)
# - read 59 sequences so far (1138605 of 3473640 bytes = 32.8%)
# - read 60 sequences so far (1157903 of 3473640 bytes = 33.3%)
# - read 61 sequences so far (1177201 of 3473640 bytes = 33.9%)
# - read 62 sequences so far (1196499 of 3473640 bytes = 34.4%)
# - read 63 sequences so far (1215797 of 3473640 bytes = 35.0%)
# - read 64 sequences so far (1235095 of 3473640 bytes = 35.6%)
# - read 65 sequences so far (1254393 of 3473640 bytes = 36.1%)
# - read 66 sequences so far (1273691 of 3473640 bytes = 36.7%)
# - read 67 sequences so far (1292989 of 3473640 bytes = 37.2%)
# - read 68 sequences so far (1312287 of 3473640 bytes = 37.8%)
# - read 69 sequences so far (1331585 of 3473640 bytes = 38.3%)
# - read 70 sequences so far (1350883 of 3473640 bytes = 38.9%)
# - read 71 sequences so far (1370181 of 3473640 bytes = 39.4%)
# - read 72 sequences so far (1389479 of 3473640 bytes = 40.0%)
# - read 73 sequences so far (1408777 of 3473640 bytes = 40.6%)
# - read 74 sequences so far (1428075 of 3473640 bytes = 41.1%)
# - read 75 sequences so far (1447373 of 3473640 bytes = 41.7%)
# - read 76 sequences so far (1466671 of 3473640 bytes = 42.2%)
# - read 77 sequences so far (1485969 of 3473640 bytes = 42.8%)
# - read 78 sequences so far (1505267 of 3473640 bytes = 43.3%)
# - read 79 sequences so far (1524565 of 3473640 bytes = 43.9%)
# - read 80 sequences so far (1543863 of 3473640 bytes = 44.4%)
# - read 81 sequences so far (1563161 of 3473640 bytes = 45.0%)
# - read 82 sequences so far (1582459 of 3473640 bytes = 45.6%)
# - read 83 sequences so far (1601757 of 3473640 bytes = 46.1%)
# - read 84 sequences so far (1621055 of 3473640 bytes = 46.7%)
# - read 85 sequences so far (1640353 of 3473640 bytes = 47.2%)
# - read 86 sequences so far (1659651 of 3473640 bytes = 47.8%)
# - read 87 sequences so far (1678949 of 3473640 bytes = 48.3%)
# - read 88 sequences so far (1698247 of 3473640 bytes = 48.9%)
# - read 89 sequences so far (1717545 of 3473640 bytes = 49.4%)
# - read 90 sequences so far (1736843 of 3473640 bytes = 50.0%)
# - read 91 sequences so far (1756141 of 3473640 bytes = 50.6%)
# - read 92 sequences so far (1775439 of 3473640 bytes = 51.1%)
# - read 93 sequences so far (1794737 of 3473640 bytes = 51.7%)
# - read 94 sequences so far (1814035 of 3473640 bytes = 52.2%)
# - read 95 sequences so far (1833333 of 3473640 bytes = 52.8%)
# - read 96 sequences so far (1852631 of 3473640 bytes = 53.3%)
# - read 97 sequences so far (1871929 of 3473640 bytes = 53.9%)
# - read 98 sequences so far (1891227 of 3473640 bytes = 54.4%)
# - read 99 sequences so far (1910525 of 3473640 bytes = 55.0%)
# - read 100 sequences so far (1929823 of 3473640 bytes = 55.6%)
# - read 101 sequences so far (1949121 of 3473640 bytes = 56.1%)
# - read 102 sequences so far (1968419 of 3473640 bytes = 56.7%)
# - read 103 sequences so far (1987717 of 3473640 bytes = 57.2%)
# - read 104 sequences so far (2007015 of 3473640 bytes = 57.8%)
# - read 105 sequences so far (2026313 of 3473640 bytes = 58.3%)
# - read 106 sequences so far (2045611 of 3473640 bytes = 58.9%)
# - read 107 sequences so far (2064909 of 3473640 bytes = 59.4%)
# - read 108 sequences so far (2084207 of 3473640 bytes = 60.0%)
# - read 109 sequences so far (2103505 of 3473640 bytes = 60.6%)
# - read 110 sequences so far (2122803 of 3473640 bytes = 61.1%)
# - read 111 sequences so far (2142101 of 3473640 bytes = 61.7%)
# - read 112 sequences so far (2161399 of 3473640 bytes = 62.2%)
# - read 113 sequences so far (2180697 of 3473640 bytes = 62.8%)
# - read 114 sequences so far (2199995 of 3473640 bytes = 63.3%)
# - read 115 sequences so far (2219293 of 3473640 bytes = 63.9%)
# - read 116 sequences so far (2238591 of 3473640 bytes = 64.4%)
# - read 117 sequences so far (2257889 of 3473640 bytes = 65.0%)
# - read 118 sequences so far (2277187 of 3473640 bytes = 65.6%)
# - read 119 sequences so far (2296485 of 3473640 bytes = 66.1%)
# - read 120 sequences so far (2315783 of 3473640 bytes = 66.7%)
# - read 121 sequences so far (2335081 of 3473640 bytes = 67.2%)
# - read 122 sequences so far (2354379 of 3473640 bytes = 67.8%)
# - read 123 sequences so far (2373677 of 3473640 bytes = 68.3%)
# - read 124 sequences so far (2392975 of 3473640 bytes = 68.9%)
# - read 125 sequences so far (2412273 of 3473640 bytes = 69.4%)
# - read 126 sequences so far (2431571 of 3473640 bytes = 70.0%)
# - read 127 sequences so far (2450869 of 3473640 bytes = 70.6%)
# - read 128 sequences so far (2470167 of 3473640 bytes = 71.1%)
# - read 129 sequences so far (2489465 of 3473640 bytes = 71.7%)
# - read 130 sequences so far (2508763 of 3473640 bytes = 72.2%)
# - read 131 sequences so far (2528061 of 3473640 bytes = 72.8%)
# - read 132 sequences so far (2547359 of 3473640 bytes = 73.3%)
# - read 133 sequences so far (2566657 of 3473640 bytes = 73.9%)
# - read 134 sequences so far (2585955 of 3473640 bytes = 74.4%)
# - read 135 sequences so far (2605253 of 3473640 bytes = 75.0%)
# - read 136 sequences so far (2624551 of 3473640 bytes = 75.6%)
# - read 137 sequences so far (2643849 of 3473640 bytes = 76.1%)
# - read 138 sequences so far (2663147 of 3473640 bytes = 76.7%)
# - read 139 sequences so far (2682445 of 3473640 bytes = 77.2%)
# - read 140 sequences so far (2701743 of 3473640 bytes = 77.8%)
# - read 141 sequences so far (2721041 of 3473640 bytes = 78.3%)
# - read 142 sequences so far (2740339 of 3473640 bytes = 78.9%)
# - read 143 sequences so far (2759637 of 3473640 bytes = 79.4%)
# - read 144 sequences so far (2778935 of 3473640 bytes = 80.0%)
# - read 145 sequences so far (2798233 of 3473640 bytes = 80.6%)
# - read 146 sequences so far (2817531 of 3473640 bytes = 81.1%)
# - read 147 sequences so far (2836829 of 3473640 bytes = 81.7%)
# - read 148 sequences so far (2856127 of 3473640 bytes = 82.2%)
# - read 149 sequences so far (2875425 of 3473640 bytes = 82.8%)
# - read 150 sequences so far (2894723 of 3473640 bytes = 83.3%)
# - read 151 sequences so far (2914021 of 3473640 bytes = 83.9%)
# - read 152 sequences so far (2933319 of 3473640 bytes = 84.4%)
# - read 153 sequences so far (2952617 of 3473640 bytes = 85.0%)
# - read 154 sequences so far (2971915 of 3473640 bytes = 85.6%)
# - read 155 sequences so far (2991213 of 3473640 bytes = 86.1%)
# - read 156 sequences so far (3010511 of 3473640 bytes = 86.7%)
# - read 157 sequences so far (3029809 of 3473640 bytes = 87.2%)
# - read 158 sequences so far (3049107 of 3473640 bytes = 87.8%)
# - read 159 sequences so far (3068405 of 3473640 bytes = 88.3%)
# - read 160 sequences so far (3087703 of 3473640 bytes = 88.9%)
# - read 161 sequences so far (3107001 of 3473640 bytes = 89.4%)
# - read 162 sequences so far (3126299 of 3473640 bytes = 90.0%)
# - read 163 sequences so far (3145597 of 3473640 bytes = 90.6%)
# - read 164 sequences so far (3164895 of 3473640 bytes = 91.1%)
# - read 165 sequences so far (3184193 of 3473640 bytes = 91.7%)
# - read 166 sequences so far (3203491 of 3473640 bytes = 92.2%)
# - read 167 sequences so far (3222789 of 3473640 bytes = 92.8%)
# - read 168 sequences so far (3242087 of 3473640 bytes = 93.3%)
# - read 169 sequences so far (3261385 of 3473640 bytes = 93.9%)
# - read 170 sequences so far (3280683 of 3473640 bytes = 94.4%)
# - read 171 sequences so far (3299981 of 3473640 bytes = 95.0%)
# - read 172 sequences so far (3319279 of 3473640 bytes = 95.6%)
# - read 173 sequences so far (3338577 of 3473640 bytes = 96.1%)
# - read 174 sequences so far (3357875 of 3473640 bytes = 96.7%)
# - read 175 sequences so far (3377173 of 3473640 bytes = 97.2%)
# - read 176 sequences so far (3396471 of 3473640 bytes = 97.8%)
# - read 177 sequences so far (3415769 of 3473640 bytes = 98.3%)
# - read 178 sequences so far (3435067 of 3473640 bytes = 98.9%)
# - read 179 sequences so far (3454365 of 3473640 bytes = 99.4%)
# - read 180 sequences so far (3473640 of 3473640 bytes = 100.0%)
# Analysing fasta file results/Zaire_ebolavirus_aligned_headers_adjusted.afa
# - analysed 0 / 180 sequences
# - analysed 1 / 180 sequences
# - analysed 2 / 180 sequences
# - analysed 3 / 180 sequences
# - analysed 4 / 180 sequences
# - analysed 5 / 180 sequences
# - analysed 6 / 180 sequences
# - analysed 7 / 180 sequences
# - analysed 8 / 180 sequences
# - analysed 9 / 180 sequences
# - analysed 10 / 180 sequences
# - analysed 11 / 180 sequences
# - analysed 12 / 180 sequences
# - analysed 13 / 180 sequences
# - analysed 14 / 180 sequences
# - analysed 15 / 180 sequences
# - analysed 16 / 180 sequences
# - analysed 17 / 180 sequences
# - analysed 18 / 180 sequences
# - analysed 19 / 180 sequences
# - analysed 20 / 180 sequences
# - analysed 21 / 180 sequences
# - analysed 22 / 180 sequences
# - analysed 23 / 180 sequences
# - analysed 24 / 180 sequences
# - analysed 25 / 180 sequences
# - analysed 26 / 180 sequences
# - analysed 27 / 180 sequences
# - analysed 28 / 180 sequences
# - analysed 29 / 180 sequences
# - analysed 30 / 180 sequences
# - analysed 31 / 180 sequences
# - analysed 32 / 180 sequences
# - analysed 33 / 180 sequences
# - analysed 34 / 180 sequences
# - analysed 35 / 180 sequences
# - analysed 36 / 180 sequences
# - analysed 37 / 180 sequences
# - analysed 38 / 180 sequences
# - analysed 39 / 180 sequences
# - analysed 40 / 180 sequences
# - analysed 41 / 180 sequences
# - analysed 42 / 180 sequences
# - analysed 43 / 180 sequences
# - analysed 44 / 180 sequences
# - analysed 45 / 180 sequences
# - analysed 46 / 180 sequences
# - analysed 47 / 180 sequences
# - analysed 48 / 180 sequences
# - analysed 49 / 180 sequences
# - analysed 50 / 180 sequences
# - analysed 51 / 180 sequences
# - analysed 52 / 180 sequences
# - analysed 53 / 180 sequences
# - analysed 54 / 180 sequences
# - analysed 55 / 180 sequences
# - analysed 56 / 180 sequences
# - analysed 57 / 180 sequences
# - analysed 58 / 180 sequences
# - analysed 59 / 180 sequences
# - analysed 60 / 180 sequences
# - analysed 61 / 180 sequences
# - analysed 62 / 180 sequences
# - analysed 63 / 180 sequences
# - analysed 64 / 180 sequences
# - analysed 65 / 180 sequences
# - analysed 66 / 180 sequences
# - analysed 67 / 180 sequences
# - analysed 68 / 180 sequences
# - analysed 69 / 180 sequences
# - analysed 70 / 180 sequences
# - analysed 71 / 180 sequences
# - analysed 72 / 180 sequences
# - analysed 73 / 180 sequences
# - analysed 74 / 180 sequences
# - analysed 75 / 180 sequences
# WARNING (sequence 'KP096421.1|2014-11-10'): ambiguous state Y at site 9267 changed to N
# - analysed 76 / 180 sequences
# - analysed 77 / 180 sequences
# - analysed 78 / 180 sequences
# - analysed 79 / 180 sequences
# - analysed 80 / 180 sequences
# - analysed 81 / 180 sequences
# - analysed 82 / 180 sequences
# - analysed 83 / 180 sequences
# - analysed 84 / 180 sequences
# - analysed 85 / 180 sequences
# - analysed 86 / 180 sequences
# - analysed 87 / 180 sequences
# - analysed 88 / 180 sequences
# - analysed 89 / 180 sequences
# - analysed 90 / 180 sequences
# - analysed 91 / 180 sequences
# - analysed 92 / 180 sequences
# - analysed 93 / 180 sequences
# - analysed 94 / 180 sequences
# - analysed 95 / 180 sequences
# - analysed 96 / 180 sequences
# - analysed 97 / 180 sequences
# - analysed 98 / 180 sequences
# - analysed 99 / 180 sequences
# - analysed 100 / 180 sequences
# - analysed 101 / 180 sequences
# - analysed 102 / 180 sequences
# - analysed 103 / 180 sequences
# - analysed 104 / 180 sequences
# - analysed 105 / 180 sequences
# - analysed 106 / 180 sequences
# - analysed 107 / 180 sequences
# - analysed 108 / 180 sequences
# - analysed 109 / 180 sequences
# - analysed 110 / 180 sequences
# - analysed 111 / 180 sequences
# - analysed 112 / 180 sequences
# - analysed 113 / 180 sequences
# - analysed 114 / 180 sequences
# - analysed 115 / 180 sequences
# - analysed 116 / 180 sequences
# - analysed 117 / 180 sequences
# - analysed 118 / 180 sequences
# - analysed 119 / 180 sequences
# - analysed 120 / 180 sequences
# - analysed 121 / 180 sequences
# - analysed 122 / 180 sequences
# - analysed 123 / 180 sequences
# - analysed 124 / 180 sequences
# - analysed 125 / 180 sequences
# - analysed 126 / 180 sequences
# - analysed 127 / 180 sequences
# - analysed 128 / 180 sequences
# - analysed 129 / 180 sequences
# - analysed 130 / 180 sequences
# - analysed 131 / 180 sequences
# - analysed 132 / 180 sequences
# - analysed 133 / 180 sequences
# - analysed 134 / 180 sequences
# - analysed 135 / 180 sequences
# - analysed 136 / 180 sequences
# - analysed 137 / 180 sequences
# - analysed 138 / 180 sequences
# - analysed 139 / 180 sequences
# - analysed 140 / 180 sequences
# - analysed 141 / 180 sequences
# - analysed 142 / 180 sequences
# - analysed 143 / 180 sequences
# - analysed 144 / 180 sequences
# - analysed 145 / 180 sequences
# - analysed 146 / 180 sequences
# - analysed 147 / 180 sequences
# - analysed 148 / 180 sequences
# - analysed 149 / 180 sequences
# - analysed 150 / 180 sequences
# - analysed 151 / 180 sequences
# - analysed 152 / 180 sequences
# - analysed 153 / 180 sequences
# - analysed 154 / 180 sequences
# - analysed 155 / 180 sequences
# - analysed 156 / 180 sequences
# - analysed 157 / 180 sequences
# - analysed 158 / 180 sequences
# - analysed 159 / 180 sequences
# - analysed 160 / 180 sequences
# - analysed 161 / 180 sequences
# - analysed 162 / 180 sequences
# - analysed 163 / 180 sequences
# - analysed 164 / 180 sequences
# - analysed 165 / 180 sequences
# - analysed 166 / 180 sequences
# - analysed 167 / 180 sequences
# - analysed 168 / 180 sequences
# - analysed 169 / 180 sequences
# - analysed 170 / 180 sequences
# - analysed 171 / 180 sequences
# - analysed 172 / 180 sequences
# - analysed 173 / 180 sequences
# - analysed 174 / 180 sequences
# - analysed 175 / 180 sequences
# - analysed 176 / 180 sequences
# - analysed 177 / 180 sequences
# - analysed 178 / 180 sequences
# - analysed 179 / 180 sequences
# - analysed 180 / 180 sequences
# Building rough initial tree...
# - added 0 / 180 tips
# - added 2 / 180 tips
# - added 3 / 180 tips
# - added 4 / 180 tips
# - added 5 / 180 tips
# - added 6 / 180 tips
# - added 7 / 180 tips
# - added 8 / 180 tips
# - added 9 / 180 tips
# - added 10 / 180 tips
# - added 11 / 180 tips
# - added 12 / 180 tips
# - added 13 / 180 tips
# - added 14 / 180 tips
# - added 15 / 180 tips
# - added 16 / 180 tips
# - added 17 / 180 tips
# - added 18 / 180 tips
# - added 19 / 180 tips
# - added 20 / 180 tips
# - added 21 / 180 tips
# - added 22 / 180 tips
# - added 23 / 180 tips
# - added 24 / 180 tips
# - added 25 / 180 tips
# - added 26 / 180 tips
# - added 27 / 180 tips
# - added 28 / 180 tips
# - added 29 / 180 tips
# - added 30 / 180 tips
# - added 31 / 180 tips
# - added 32 / 180 tips
# - added 33 / 180 tips
# - added 34 / 180 tips
# - added 35 / 180 tips
# - added 36 / 180 tips
# - added 37 / 180 tips
# - added 38 / 180 tips
# - added 39 / 180 tips
# - added 40 / 180 tips
# - added 41 / 180 tips
# - added 42 / 180 tips
# - added 43 / 180 tips
# - added 44 / 180 tips
# - added 45 / 180 tips
# - added 46 / 180 tips
# - added 47 / 180 tips
# - added 48 / 180 tips
# - added 49 / 180 tips
# - added 50 / 180 tips
# - added 51 / 180 tips
# - added 52 / 180 tips
# - added 53 / 180 tips
# - added 54 / 180 tips
# - added 55 / 180 tips
# - added 56 / 180 tips
# - added 57 / 180 tips
# - added 58 / 180 tips
# - added 59 / 180 tips
# - added 60 / 180 tips
# - added 61 / 180 tips
# - added 62 / 180 tips
# - added 63 / 180 tips
# - added 64 / 180 tips
# - added 65 / 180 tips
# - added 66 / 180 tips
# - added 67 / 180 tips
# - added 68 / 180 tips
# - added 69 / 180 tips
# - added 70 / 180 tips
# - added 71 / 180 tips
# - added 72 / 180 tips
# - added 73 / 180 tips
# - added 74 / 180 tips
# - added 75 / 180 tips
# - added 76 / 180 tips
# - added 77 / 180 tips
# - added 78 / 180 tips
# - added 79 / 180 tips
# - added 80 / 180 tips
# - added 81 / 180 tips
# - added 82 / 180 tips
# - added 83 / 180 tips
# - added 84 / 180 tips
# - added 85 / 180 tips
# - added 86 / 180 tips
# - added 87 / 180 tips
# - added 88 / 180 tips
# - added 89 / 180 tips
# - added 90 / 180 tips
# - added 91 / 180 tips
# - added 92 / 180 tips
# - added 93 / 180 tips
# - added 94 / 180 tips
# - added 95 / 180 tips
# - added 96 / 180 tips
# - added 97 / 180 tips
# - added 98 / 180 tips
# - added 99 / 180 tips
# - added 100 / 180 tips
# - added 101 / 180 tips
# - added 102 / 180 tips
# - added 103 / 180 tips
# - added 104 / 180 tips
# - added 105 / 180 tips
# - added 106 / 180 tips
# - added 107 / 180 tips
# - added 108 / 180 tips
# - added 109 / 180 tips
# - added 110 / 180 tips
# - added 111 / 180 tips
# - added 112 / 180 tips
# - added 113 / 180 tips
# - added 114 / 180 tips
# - added 115 / 180 tips
# - added 116 / 180 tips
# - added 117 / 180 tips
# - added 118 / 180 tips
# - added 119 / 180 tips
# - added 120 / 180 tips
# - added 121 / 180 tips
# - added 122 / 180 tips
# - added 123 / 180 tips
# - added 124 / 180 tips
# - added 125 / 180 tips
# - added 126 / 180 tips
# - added 127 / 180 tips
# - added 128 / 180 tips
# - added 129 / 180 tips
# - added 130 / 180 tips
# - added 131 / 180 tips
# - added 132 / 180 tips
# - added 133 / 180 tips
# - added 134 / 180 tips
# - added 135 / 180 tips
# - added 136 / 180 tips
# - added 137 / 180 tips
# - added 138 / 180 tips
# - added 139 / 180 tips
# - added 140 / 180 tips
# - added 141 / 180 tips
# - added 142 / 180 tips
# - added 143 / 180 tips
# - added 144 / 180 tips
# - added 145 / 180 tips
# - added 146 / 180 tips
# - added 147 / 180 tips
# - added 148 / 180 tips
# - added 149 / 180 tips
# - added 150 / 180 tips
# - added 151 / 180 tips
# - added 152 / 180 tips
# - added 153 / 180 tips
# - added 154 / 180 tips
# - added 155 / 180 tips
# - added 156 / 180 tips
# - added 157 / 180 tips
# - added 158 / 180 tips
# - added 159 / 180 tips
# - added 160 / 180 tips
# - added 161 / 180 tips
# - added 162 / 180 tips
# - added 163 / 180 tips
# - added 164 / 180 tips
# - added 165 / 180 tips
# - added 166 / 180 tips
# - added 167 / 180 tips
# - added 168 / 180 tips
# - added 169 / 180 tips
# - added 170 / 180 tips
# - added 171 / 180 tips
# - added 172 / 180 tips
# - added 173 / 180 tips
# - added 174 / 180 tips
# - added 175 / 180 tips
# - added 176 / 180 tips
# - added 177 / 180 tips
# - added 178 / 180 tips
# - added 179 / 180 tips
# - added 180 / 180 tips
# Built initial tree with 180 tips
# # Parallelism: 2
# 0.0 M steps/s, Step 0, log_posterior = -68847.31, log_G = -63733.92, log_coal = -9343.97, log_other_priors = 4230.58, num_muts = 1259, T = 391436.77, t_MRCA = 1992-09-15, n0 = 1095.0, g = 0.0000, mu = 1 * 10^-3 subst / site / year, M_ts = 988, M_tv = 271, kappa = 1, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6054, 4053, 3753, 5099], num_muts_ab counts: [52, 246, 37, 36, 15, 232, 227, 39, 36, 29, 283, 27]
# 0.0 M steps/s, Step 450000, log_posterior = -41973.22, log_G = -44510.39, log_coal = -1690.03, log_other_priors = 4227.20, num_muts = 1161, T = 101191.21, t_MRCA = 1937-10-21, n0 = 4398.7, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 904, M_tv = 257, kappa = 7.36, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6066, 4048, 3739, 5106], num_muts_ab counts: [56, 232, 34, 26, 13, 214, 207, 38, 26, 30, 251, 34]
# 0.3 M steps/s, Step 900000, log_posterior = -41852.31, log_G = -44401.87, log_coal = -1677.70, log_other_priors = 4227.26, num_muts = 1157, T = 97224.74, t_MRCA = 1938-05-25, n0 = 4401.9, g = -0.0000, mu = 0.24 * 10^-3 subst / site / year, M_ts = 903, M_tv = 254, kappa = 7.09, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6058, 4068, 3738, 5095], num_muts_ab counts: [49, 228, 35, 33, 16, 224, 209, 34, 26, 25, 242, 36]
# 0.2 M steps/s, Step 1350000, log_posterior = -41556.56, log_G = -44095.14, log_coal = -1688.69, log_other_priors = 4227.27, num_muts = 1136, T = 98502.49, t_MRCA = 1938-09-23, n0 = 3799.3, g = -0.0001, mu = 0.21 * 10^-3 subst / site / year, M_ts = 890, M_tv = 246, kappa = 7.72, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6051, 4045, 3758, 5105], num_muts_ab counts: [52, 216, 34, 30, 12, 203, 215, 33, 33, 26, 256, 26]
# 0.2 M steps/s, Step 1800000, log_posterior = -41531.56, log_G = -44086.54, log_coal = -1672.15, log_other_priors = 4227.14, num_muts = 1136, T = 97830.84, t_MRCA = 1936-07-20, n0 = 4180.3, g = 0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 890, M_tv = 246, kappa = 7.88, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6051, 4045, 3758, 5105], num_muts_ab counts: [52, 215, 35, 29, 13, 204, 215, 33, 32, 26, 256, 26]
# 0.2 M steps/s, Step 2250000, log_posterior = -41576.13, log_G = -44122.01, log_coal = -1681.23, log_other_priors = 4227.12, num_muts = 1138, T = 98168.95, t_MRCA = 1938-10-02, n0 = 4709.5, g = 0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 890, M_tv = 248, kappa = 7.42, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6039, 4067, 3753, 5100], num_muts_ab counts: [46, 212, 29, 34, 14, 222, 218, 34, 26, 31, 238, 34]
# 0.3 M steps/s, Step 2700000, log_posterior = -41567.24, log_G = -44109.97, log_coal = -1684.40, log_other_priors = 4227.13, num_muts = 1137, T = 98286.08, t_MRCA = 1939-09-20, n0 = 4833.1, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 889, M_tv = 248, kappa = 7.25, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6039, 4067, 3753, 5100], num_muts_ab counts: [46, 212, 29, 34, 14, 221, 218, 34, 26, 31, 238, 34]
# 0.2 M steps/s, Step 3150000, log_posterior = -41443.25, log_G = -44013.91, log_coal = -1656.63, log_other_priors = 4227.29, num_muts = 1134, T = 93892.95, t_MRCA = 1939-12-10, n0 = 4045.4, g = 0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 887, M_tv = 247, kappa = 7.32, pi = [0.31, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [54, 223, 39, 27, 13, 199, 208, 34, 26, 23, 257, 31]
# 0.2 M steps/s, Step 3600000, log_posterior = -41477.50, log_G = -44031.12, log_coal = -1673.50, log_other_priors = 4227.13, num_muts = 1135, T = 93999.46, t_MRCA = 1942-06-29, n0 = 4949.7, g = 0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 887, M_tv = 248, kappa = 7.15, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [54, 223, 38, 27, 13, 199, 208, 34, 28, 23, 257, 31]
# 0.2 M steps/s, Step 4050000, log_posterior = -41440.34, log_G = -44003.92, log_coal = -1663.82, log_other_priors = 4227.40, num_muts = 1134, T = 93097.70, t_MRCA = 1941-07-26, n0 = 4235.8, g = 0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 887, M_tv = 247, kappa = 6.65, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [54, 223, 39, 27, 13, 199, 208, 34, 26, 23, 257, 31]
# 0.3 M steps/s, Step 4500000, log_posterior = -41351.81, log_G = -43931.80, log_coal = -1647.43, log_other_priors = 4227.42, num_muts = 1132, T = 89695.60, t_MRCA = 1942-05-12, n0 = 3524.9, g = 0.0000, mu = 0.24 * 10^-3 subst / site / year, M_ts = 885, M_tv = 247, kappa = 7.35, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [55, 223, 39, 27, 13, 198, 208, 33, 26, 23, 256, 31]
# 0.3 M steps/s, Step 4950000, log_posterior = -41379.98, log_G = -43956.42, log_coal = -1651.22, log_other_priors = 4227.66, num_muts = 1132, T = 91576.28, t_MRCA = 1941-02-05, n0 = 3157.9, g = 0.0000, mu = 0.24 * 10^-3 subst / site / year, M_ts = 885, M_tv = 247, kappa = 6.79, pi = [0.31, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [55, 223, 38, 27, 13, 198, 208, 33, 27, 23, 256, 31]
# 0.3 M steps/s, Step 5400000, log_posterior = -41419.14, log_G = -43981.23, log_coal = -1665.28, log_other_priors = 4227.37, num_muts = 1131, T = 94912.18, t_MRCA = 1939-11-12, n0 = 4268.7, g = 0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 884, M_tv = 247, kappa = 6.74, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [55, 223, 38, 27, 13, 198, 208, 33, 27, 23, 255, 31]
# 0.3 M steps/s, Step 5850000, log_posterior = -41516.42, log_G = -44042.17, log_coal = -1701.58, log_other_priors = 4227.33, num_muts = 1131, T = 100200.80, t_MRCA = 1939-12-31, n0 = 3804.9, g = -0.0001, mu = 0.22 * 10^-3 subst / site / year, M_ts = 884, M_tv = 247, kappa = 7.41, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [55, 223, 38, 27, 13, 198, 208, 33, 27, 23, 255, 31]
# 0.3 M steps/s, Step 6300000, log_posterior = -41464.97, log_G = -44027.80, log_coal = -1664.40, log_other_priors = 4227.23, num_muts = 1134, T = 94978.59, t_MRCA = 1940-04-28, n0 = 4215.3, g = 0.0000, mu = 0.24 * 10^-3 subst / site / year, M_ts = 887, M_tv = 247, kappa = 7.4, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6063, 4039, 3746, 5111], num_muts_ab counts: [55, 223, 38, 27, 13, 199, 208, 33, 27, 23, 257, 31]
# 0.3 M steps/s, Step 6750000, log_posterior = -41477.70, log_G = -44012.27, log_coal = -1692.52, log_other_priors = 4227.10, num_muts = 1129, T = 100084.83, t_MRCA = 1940-01-18, n0 = 4966.5, g = 0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 882, M_tv = 247, kappa = 7.28, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6045, 4064, 3758, 5092], num_muts_ab counts: [47, 213, 35, 32, 15, 217, 214, 32, 32, 28, 238, 26]
# 0.3 M steps/s, Step 7200000, log_posterior = -41413.68, log_G = -43966.53, log_coal = -1674.47, log_other_priors = 4227.31, num_muts = 1129, T = 96064.71, t_MRCA = 1940-08-20, n0 = 4037.3, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 882, M_tv = 247, kappa = 7.26, pi = [0.31, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6057, 4056, 3739, 5107], num_muts_ab counts: [48, 232, 29, 35, 12, 209, 198, 32, 30, 30, 243, 31]
# 0.3 M steps/s, Step 7650000, log_posterior = -41314.56, log_G = -43871.85, log_coal = -1669.95, log_other_priors = 4227.25, num_muts = 1124, T = 94420.05, t_MRCA = 1941-02-09, n0 = 4010.9, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 878, M_tv = 246, kappa = 7.56, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6050, 4073, 3744, 5092], num_muts_ab counts: [47, 222, 33, 35, 14, 220, 206, 31, 27, 28, 230, 31]
# 0.3 M steps/s, Step 8100000, log_posterior = -41256.83, log_G = -43792.96, log_coal = -1691.16, log_other_priors = 4227.28, num_muts = 1115, T = 99142.81, t_MRCA = 1940-01-05, n0 = 4236.0, g = -0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 870, M_tv = 245, kappa = 7.18, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6036, 4056, 3763, 5104], num_muts_ab counts: [49, 205, 32, 31, 12, 203, 223, 32, 30, 27, 239, 32]
# 0.3 M steps/s, Step 8550000, log_posterior = -41492.98, log_G = -44039.50, log_coal = -1680.56, log_other_priors = 4227.08, num_muts = 1132, T = 97519.67, t_MRCA = 1938-08-21, n0 = 4027.3, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 882, M_tv = 250, kappa = 8.31, pi = [0.33, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6057, 4056, 3744, 5102], num_muts_ab counts: [48, 233, 32, 33, 15, 204, 200, 34, 33, 31, 245, 24]
# 0.3 M steps/s, Step 9000000, log_posterior = -41459.67, log_G = -43990.22, log_coal = -1696.72, log_other_priors = 4227.27, num_muts = 1124, T = 104787.45, t_MRCA = 1933-04-16, n0 = 4592.1, g = -0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 878, M_tv = 246, kappa = 6.85, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6064, 4049, 3736, 5110], num_muts_ab counts: [50, 233, 35, 31, 13, 199, 197, 33, 26, 27, 249, 31]
# 0.3 M steps/s, Step 9450000, log_posterior = -41406.72, log_G = -43916.06, log_coal = -1717.54, log_other_priors = 4226.88, num_muts = 1119, T = 104423.76, t_MRCA = 1938-09-20, n0 = 6043.8, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 871, M_tv = 248, kappa = 7.38, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6058, 4044, 3748, 5109], num_muts_ab counts: [55, 226, 31, 28, 11, 197, 203, 35, 30, 29, 245, 29]
# 0.4 M steps/s, Step 9900000, log_posterior = -41279.83, log_G = -43797.84, log_coal = -1708.95, log_other_priors = 4226.96, num_muts = 1113, T = 102608.16, t_MRCA = 1937-07-23, n0 = 5820.8, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 871, M_tv = 242, kappa = 7.19, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6046, 4063, 3760, 5090], num_muts_ab counts: [53, 211, 32, 27, 13, 214, 214, 31, 32, 28, 232, 26]
# 0.4 M steps/s, Step 10350000, log_posterior = -41420.19, log_G = -43967.54, log_coal = -1679.76, log_other_priors = 4227.12, num_muts = 1128, T = 96899.34, t_MRCA = 1939-01-03, n0 = 3816.2, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 880, M_tv = 248, kappa = 8.41, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6047, 4062, 3754, 5096], num_muts_ab counts: [54, 219, 31, 26, 12, 216, 217, 36, 25, 31, 228, 33]
# 0.4 M steps/s, Step 10800000, log_posterior = -41250.98, log_G = -43773.22, log_coal = -1704.79, log_other_priors = 4227.03, num_muts = 1111, T = 103298.59, t_MRCA = 1936-08-10, n0 = 5191.1, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 870, M_tv = 241, kappa = 7.35, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6050, 4075, 3753, 5081], num_muts_ab counts: [51, 214, 34, 29, 12, 224, 212, 32, 28, 25, 220, 30]
# 0.4 M steps/s, Step 11250000, log_posterior = -41243.45, log_G = -43804.93, log_coal = -1666.04, log_other_priors = 4227.52, num_muts = 1117, T = 97599.51, t_MRCA = 1937-04-18, n0 = 3681.8, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 874, M_tv = 243, kappa = 6.72, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6050, 4058, 3761, 5090], num_muts_ab counts: [51, 212, 37, 25, 14, 210, 217, 33, 32, 24, 235, 27]
# 0.4 M steps/s, Step 11700000, log_posterior = -41354.16, log_G = -43886.55, log_coal = -1694.87, log_other_priors = 4227.26, num_muts = 1120, T = 100986.15, t_MRCA = 1937-10-01, n0 = 3554.5, g = -0.0001, mu = 0.21 * 10^-3 subst / site / year, M_ts = 877, M_tv = 243, kappa = 8.08, pi = [0.32, 0.21, 0.2, 0.28], alpha OFF, nu = 1.000, Root Seq counts: [6046, 4063, 3754, 5096], num_muts_ab counts: [50, 213, 35, 28, 13, 214, 216, 32, 25, 28, 234, 32]
# 0.4 M steps/s, Step 12150000, log_posterior = -41404.85, log_G = -43920.35, log_coal = -1711.34, log_other_priors = 4226.84, num_muts = 1120, T = 104256.04, t_MRCA = 1937-01-21, n0 = 6031.0, g = -0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 877, M_tv = 243, kappa = 7.55, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6046, 4063, 3754, 5096], num_muts_ab counts: [50, 213, 35, 28, 13, 214, 216, 32, 25, 28, 234, 32]
# 0.4 M steps/s, Step 12600000, log_posterior = -41347.19, log_G = -43881.79, log_coal = -1692.45, log_other_priors = 4227.06, num_muts = 1120, T = 100408.77, t_MRCA = 1936-05-28, n0 = 5018.7, g = -0.0000, mu = 0.23 * 10^-3 subst / site / year, M_ts = 877, M_tv = 243, kappa = 7.41, pi = [0.31, 0.22, 0.21, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6046, 4063, 3754, 5096], num_muts_ab counts: [50, 213, 36, 28, 13, 215, 216, 32, 24, 28, 233, 32]
# 0.4 M steps/s, Step 13050000, log_posterior = -41362.84, log_G = -43893.27, log_coal = -1696.88, log_other_priors = 4227.31, num_muts = 1120, T = 101822.22, t_MRCA = 1936-10-05, n0 = 4697.2, g = -0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 877, M_tv = 243, kappa = 6.59, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6046, 4063, 3754, 5096], num_muts_ab counts: [50, 213, 35, 28, 13, 215, 216, 32, 25, 28, 233, 32]
# 0.3 M steps/s, Step 13500000, log_posterior = -41283.14, log_G = -43813.92, log_coal = -1696.24, log_other_priors = 4227.02, num_muts = 1115, T = 101852.26, t_MRCA = 1936-04-10, n0 = 4478.2, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 876, M_tv = 239, kappa = 8.1, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 213, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.3 M steps/s, Step 13950000, log_posterior = -41277.55, log_G = -43799.74, log_coal = -1705.02, log_other_priors = 4227.21, num_muts = 1114, T = 102101.40, t_MRCA = 1936-03-18, n0 = 4322.1, g = -0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 7.38, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.3 M steps/s, Step 14400000, log_posterior = -41238.08, log_G = -43779.61, log_coal = -1685.61, log_other_priors = 4227.15, num_muts = 1114, T = 100284.59, t_MRCA = 1937-03-25, n0 = 4568.7, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 7.42, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.3 M steps/s, Step 14850000, log_posterior = -41325.51, log_G = -43833.38, log_coal = -1719.17, log_other_priors = 4227.04, num_muts = 1114, T = 105230.64, t_MRCA = 1937-05-30, n0 = 4956.0, g = -0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 7.55, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.3 M steps/s, Step 15300000, log_posterior = -41270.82, log_G = -43805.29, log_coal = -1692.41, log_other_priors = 4226.89, num_muts = 1114, T = 102521.42, t_MRCA = 1935-07-11, n0 = 4807.0, g = -0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 8.4, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 34, 24, 12, 208, 215, 31, 25, 29, 240, 31]
# 0.3 M steps/s, Step 15750000, log_posterior = -41337.59, log_G = -43848.22, log_coal = -1716.19, log_other_priors = 4226.82, num_muts = 1114, T = 106632.66, t_MRCA = 1935-04-20, n0 = 5445.0, g = 0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 8.13, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 34, 24, 12, 208, 215, 31, 25, 29, 240, 31]
# 0.3 M steps/s, Step 16200000, log_posterior = -41334.83, log_G = -43849.21, log_coal = -1712.60, log_other_priors = 4226.98, num_muts = 1114, T = 106395.81, t_MRCA = 1934-04-07, n0 = 5900.6, g = 0.0001, mu = 0.2 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 7.03, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.3 M steps/s, Step 16650000, log_posterior = -41344.29, log_G = -43860.25, log_coal = -1710.93, log_other_priors = 4226.88, num_muts = 1115, T = 106029.72, t_MRCA = 1934-07-21, n0 = 5357.2, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 876, M_tv = 239, kappa = 7.91, pi = [0.31, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 209, 215, 31, 26, 29, 240, 31]
# 0.4 M steps/s, Step 17100000, log_posterior = -41323.50, log_G = -43846.75, log_coal = -1703.95, log_other_priors = 4227.19, num_muts = 1115, T = 104766.62, t_MRCA = 1935-05-27, n0 = 4543.5, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 876, M_tv = 239, kappa = 7.24, pi = [0.32, 0.21, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 209, 215, 31, 26, 29, 240, 31]
# 0.4 M steps/s, Step 17550000, log_posterior = -41279.10, log_G = -43817.04, log_coal = -1689.16, log_other_priors = 4227.10, num_muts = 1114, T = 103382.30, t_MRCA = 1934-11-02, n0 = 3893.9, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 8.38, pi = [0.31, 0.21, 0.2, 0.28], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.4 M steps/s, Step 18000000, log_posterior = -41232.78, log_G = -43772.69, log_coal = -1687.24, log_other_priors = 4227.15, num_muts = 1114, T = 99614.36, t_MRCA = 1937-04-09, n0 = 4511.0, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 7.45, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.4 M steps/s, Step 18450000, log_posterior = -41242.75, log_G = -43787.81, log_coal = -1682.15, log_other_priors = 4227.22, num_muts = 1115, T = 99684.70, t_MRCA = 1937-05-31, n0 = 4413.8, g = -0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 876, M_tv = 239, kappa = 7.25, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 209, 215, 31, 26, 29, 240, 31]
# 0.4 M steps/s, Step 18900000, log_posterior = -41276.77, log_G = -43803.30, log_coal = -1700.72, log_other_priors = 4227.25, num_muts = 1114, T = 101990.67, t_MRCA = 1938-06-12, n0 = 4425.3, g = -0.0001, mu = 0.22 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 7.09, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# 0.4 M steps/s, Step 19350000, log_posterior = -41270.24, log_G = -43790.02, log_coal = -1707.28, log_other_priors = 4227.06, num_muts = 1114, T = 101060.95, t_MRCA = 1940-11-14, n0 = 5736.8, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 875, M_tv = 239, kappa = 6.81, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6048, 4053, 3755, 5103], num_muts_ab counts: [53, 212, 33, 24, 12, 208, 215, 31, 26, 29, 240, 31]
# ...
# 0.3 M steps/s, Step 75600000, log_posterior = -41311.15, log_G = -43808.90, log_coal = -1729.19, log_other_priors = 4226.95, num_muts = 1106, T = 114954.21, t_MRCA = 1927-04-04, n0 = 5608.6, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.39, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 76050000, log_posterior = -41315.44, log_G = -43815.17, log_coal = -1727.13, log_other_priors = 4226.85, num_muts = 1106, T = 115611.91, t_MRCA = 1926-08-31, n0 = 4892.7, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 8.49, pi = [0.31, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 76500000, log_posterior = -41303.53, log_G = -43815.03, log_coal = -1715.55, log_other_priors = 4227.05, num_muts = 1106, T = 115614.45, t_MRCA = 1925-05-13, n0 = 5334.2, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.14, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 76950000, log_posterior = -41354.01, log_G = -43839.03, log_coal = -1741.82, log_other_priors = 4226.85, num_muts = 1106, T = 118266.41, t_MRCA = 1925-09-23, n0 = 5842.5, g = -0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.65, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 77400000, log_posterior = -41275.55, log_G = -43793.45, log_coal = -1709.10, log_other_priors = 4226.99, num_muts = 1106, T = 113581.03, t_MRCA = 1926-02-03, n0 = 4910.3, g = -0.0000, mu = 0.19 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.82, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 77850000, log_posterior = -41355.36, log_G = -43833.44, log_coal = -1748.47, log_other_priors = 4226.55, num_muts = 1105, T = 119054.01, t_MRCA = 1926-02-03, n0 = 6519.1, g = 0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 8.57, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 78300000, log_posterior = -41312.41, log_G = -43811.04, log_coal = -1728.34, log_other_priors = 4226.97, num_muts = 1106, T = 114923.40, t_MRCA = 1926-04-21, n0 = 5368.3, g = 0.0000, mu = 0.19 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.49, pi = [0.32, 0.21, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 35, 25, 9, 203, 195, 34, 26, 25, 250, 31]
# 0.4 M steps/s, Step 78750000, log_posterior = -41363.73, log_G = -43840.95, log_coal = -1749.50, log_other_priors = 4226.73, num_muts = 1105, T = 119951.78, t_MRCA = 1925-08-22, n0 = 6824.5, g = 0.0000, mu = 0.19 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 7.5, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 79200000, log_posterior = -41273.29, log_G = -43777.51, log_coal = -1722.95, log_other_priors = 4227.18, num_muts = 1105, T = 113269.00, t_MRCA = 1927-08-06, n0 = 5131.7, g = -0.0000, mu = 0.19 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 6.78, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 79650000, log_posterior = -41306.49, log_G = -43809.50, log_coal = -1723.82, log_other_priors = 4226.83, num_muts = 1106, T = 115198.75, t_MRCA = 1926-05-22, n0 = 5634.2, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.9, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 204, 195, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 80100000, log_posterior = -41355.77, log_G = -43840.12, log_coal = -1742.51, log_other_priors = 4226.87, num_muts = 1105, T = 119862.22, t_MRCA = 1922-10-18, n0 = 5779.3, g = -0.0000, mu = 0.19 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 7.63, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 35, 25, 9, 203, 195, 34, 26, 25, 249, 31]
# 0.4 M steps/s, Step 80550000, log_posterior = -41433.73, log_G = -43899.23, log_coal = -1761.21, log_other_priors = 4226.71, num_muts = 1105, T = 126512.40, t_MRCA = 1920-12-26, n0 = 7686.2, g = 0.0000, mu = 0.16 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 7.06, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 81000000, log_posterior = -41388.47, log_G = -43875.49, log_coal = -1739.79, log_other_priors = 4226.81, num_muts = 1105, T = 123886.51, t_MRCA = 1918-03-25, n0 = 5721.0, g = -0.0001, mu = 0.17 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 7.93, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 81450000, log_posterior = -41413.29, log_G = -43888.93, log_coal = -1751.23, log_other_priors = 4226.87, num_muts = 1105, T = 125438.13, t_MRCA = 1919-04-02, n0 = 5804.8, g = -0.0001, mu = 0.17 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 7.57, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 81900000, log_posterior = -41446.01, log_G = -43919.13, log_coal = -1753.68, log_other_priors = 4226.80, num_muts = 1106, T = 126644.36, t_MRCA = 1918-07-15, n0 = 6748.8, g = -0.0000, mu = 0.16 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.25, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 35, 25, 9, 203, 196, 35, 26, 24, 249, 31]
# 0.4 M steps/s, Step 82350000, log_posterior = -41418.44, log_G = -43896.89, log_coal = -1748.33, log_other_priors = 4226.78, num_muts = 1106, T = 124630.98, t_MRCA = 1917-05-18, n0 = 6211.5, g = -0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.7, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 35, 27, 24, 249, 31]
# 0.4 M steps/s, Step 82800000, log_posterior = -41467.43, log_G = -43926.79, log_coal = -1767.30, log_other_priors = 4226.66, num_muts = 1106, T = 127930.16, t_MRCA = 1920-01-28, n0 = 6680.1, g = 0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.9, pi = [0.31, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 35, 25, 9, 203, 196, 35, 26, 24, 249, 31]
# 0.4 M steps/s, Step 83250000, log_posterior = -41422.03, log_G = -43900.80, log_coal = -1747.85, log_other_priors = 4226.62, num_muts = 1106, T = 124948.02, t_MRCA = 1919-08-02, n0 = 7052.5, g = 0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.83, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 83700000, log_posterior = -41370.05, log_G = -43861.49, log_coal = -1735.45, log_other_priors = 4226.89, num_muts = 1106, T = 120627.13, t_MRCA = 1920-12-16, n0 = 6050.1, g = 0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.32, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 84150000, log_posterior = -41404.74, log_G = -43885.05, log_coal = -1746.28, log_other_priors = 4226.59, num_muts = 1106, T = 122887.33, t_MRCA = 1920-09-01, n0 = 7344.7, g = 0.0000, mu = 0.16 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.81, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.4 M steps/s, Step 84600000, log_posterior = -41404.14, log_G = -43887.53, log_coal = -1743.59, log_other_priors = 4226.98, num_muts = 1107, T = 121515.74, t_MRCA = 1923-08-08, n0 = 6274.5, g = 0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 872, M_tv = 235, kappa = 6.76, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 250, 31]
# 0.3 M steps/s, Step 85050000, log_posterior = -41393.68, log_G = -43880.24, log_coal = -1740.20, log_other_priors = 4226.75, num_muts = 1106, T = 122660.94, t_MRCA = 1920-09-05, n0 = 6859.0, g = -0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.35, pi = [0.31, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 85500000, log_posterior = -41422.92, log_G = -43912.70, log_coal = -1736.99, log_other_priors = 4226.77, num_muts = 1108, T = 122905.43, t_MRCA = 1919-11-11, n0 = 5785.4, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 873, M_tv = 235, kappa = 8.08, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 224, 34, 25, 9, 203, 197, 35, 27, 24, 249, 31]
# 0.3 M steps/s, Step 85950000, log_posterior = -41381.87, log_G = -43867.36, log_coal = -1741.33, log_other_priors = 4226.82, num_muts = 1106, T = 121130.18, t_MRCA = 1921-03-06, n0 = 6690.5, g = 0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.16, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 35, 27, 24, 249, 31]
# 0.3 M steps/s, Step 86400000, log_posterior = -41429.63, log_G = -43898.52, log_coal = -1757.97, log_other_priors = 4226.86, num_muts = 1106, T = 124626.78, t_MRCA = 1921-06-27, n0 = 6677.6, g = -0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.01, pi = [0.31, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 35, 27, 24, 249, 31]
# 0.3 M steps/s, Step 86850000, log_posterior = -41412.36, log_G = -43897.32, log_coal = -1742.14, log_other_priors = 4227.10, num_muts = 1107, T = 122815.92, t_MRCA = 1918-12-19, n0 = 5429.4, g = -0.0000, mu = 0.17 * 10^-3 subst / site / year, M_ts = 872, M_tv = 235, kappa = 6.87, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 35, 27, 24, 250, 31]
# 0.3 M steps/s, Step 87300000, log_posterior = -41352.53, log_G = -43860.01, log_coal = -1719.58, log_other_priors = 4227.05, num_muts = 1106, T = 120239.44, t_MRCA = 1918-01-19, n0 = 5923.8, g = 0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 6.69, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 35, 25, 9, 203, 196, 34, 26, 25, 249, 31]
# 0.3 M steps/s, Step 87750000, log_posterior = -41419.90, log_G = -43905.72, log_coal = -1741.11, log_other_priors = 4226.93, num_muts = 1106, T = 125368.92, t_MRCA = 1916-09-10, n0 = 6382.2, g = 0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 6.91, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 88200000, log_posterior = -41401.05, log_G = -43892.71, log_coal = -1734.95, log_other_priors = 4226.61, num_muts = 1106, T = 123887.32, t_MRCA = 1916-12-22, n0 = 6603.1, g = 0.0000, mu = 0.16 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 8.2, pi = [0.31, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 196, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 88650000, log_posterior = -41467.74, log_G = -43945.02, log_coal = -1749.43, log_other_priors = 4226.72, num_muts = 1108, T = 126268.96, t_MRCA = 1918-07-31, n0 = 5664.7, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 873, M_tv = 235, kappa = 8.42, pi = [0.32, 0.21, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 224, 34, 25, 9, 203, 197, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 89100000, log_posterior = -41452.21, log_G = -43919.81, log_coal = -1759.34, log_other_priors = 4226.94, num_muts = 1105, T = 128866.28, t_MRCA = 1917-06-23, n0 = 6255.0, g = -0.0000, mu = 0.16 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 6.95, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
# 0.3 M steps/s, Step 89550000, log_posterior = -41406.96, log_G = -43904.75, log_coal = -1729.31, log_other_priors = 4227.10, num_muts = 1106, T = 125199.35, t_MRCA = 1915-07-21, n0 = 4495.0, g = -0.0001, mu = 0.16 * 10^-3 subst / site / year, M_ts = 871, M_tv = 235, kappa = 7.69, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 250, 31]
# 0.3 M steps/s, Step 90000000, log_posterior = -41503.88, log_G = -43955.78, log_coal = -1774.63, log_other_priors = 4226.53, num_muts = 1105, T = 133260.45, t_MRCA = 1914-11-27, n0 = 7660.6, g = -0.0000, mu = 0.16 * 10^-3 subst / site / year, M_ts = 870, M_tv = 235, kappa = 7.88, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4044, 3745, 5108], num_muts_ab counts: [50, 223, 34, 25, 9, 203, 195, 34, 27, 25, 249, 31]
#     <h2 style='color:green'>All done! 🎉</h2>
#     <p>Files generated in this notebook are in the left-hand file browser (or in the folder you set as <code>outfolder</code>).</p>
#     <ul>
#       <li>Aligned FASTA: <code>Zaire_ebolavirus_aligned_headers_adjusted.afa</code></li>
#       <li>Delphy output (.dphy): <code>Zaire_ebolavirus_delphy_out.dphy</code></li>
#       <li>Delphy log (.log): <code>Zaire_ebolavirus_delphy_beast.log</code></li>
#       <li>Delphy trees (.trees): <code>Zaire_ebolavirus_delphy_beast.trees</code></li>
#     </ul>
#     <p>We recommend downloading the <code>.afa</code>, <code>.dphy</code>, and <code>metadata.csv</code> files. To visualize .dphy files online, try <a href='https://delphy.fathom.info/' target='_blank'>delphy.fathom.info</a>.</p>
# CPU times: user 4.07 s, sys: 536 ms, total: 4.61 s
# Wall time: 5min 31s
