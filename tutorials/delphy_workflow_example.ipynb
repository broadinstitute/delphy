# %% [markdown]
# <a href="https://colab.research.google.com/github/broadinstitute/delphy/blob/main/tutorials/delphy_workflow_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="font-size: 2.5em; color: #2C3E50;">Running <a href="https://github.com/broadinstitute/delphy" target="_blank">Delphy</a> is as simple as 1, 2, 3 – Ebolavirus Example</h1>
#     <h2 style="font-size: 1.5em; color: #34495E;">Phylogenetic Tree Generation with Delphy on Ebolavirus Sequences</h2>
# </div>
#
# This notebook demonstrates how to generate a phylogenetic tree using [Delphy](https://github.com/broadinstitute/delphy) on viral sequences obtained from the [NCBI Virus Database](https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/). Optionally, you can also upload your own sequences to be included in the analysis.
#
# We will utilize the following tools:
# - [**gget**](https://pachterlab.github.io/gget/en/virus.html) to download viral sequences from the [NCBI Virus Database](https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/)
# - [**MAFFT**](https://mafft.cbrc.jp/alignment/server/index.html) for creating a Multiple-Sequence Alignment (MSA)
# - [**Delphy**](https://github.com/broadinstitute/delphy) to generate the phylogenetic tree
#
# In this example notebook, we already filled out the NCBI Virus filters and options below to download and analyze all **complete *Zaire ebolavirus* sequences from *Homo sapiens* hosts collected between January 01, 2014 and June 30, 2014**. All generated files will be saved in the **results/** folder, unless you specify a different output folder below.
#
# Simply **click `Runtime` -> `Run all`** at the top to run this example notebook.
#
# If you encounter any problems or questions while using this notebook, please [report them here](https://github.com/broadinstitute/delphy/issues).
#
# Total runtime: ~4 min
# ___
# ___

# %% [markdown]
# # 1. Apply filters to download sequences from [NCBI Virus](https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/)

# %%
#@title gget virus filtering options:
#@markdown Set any non-boolean filter to `None` to disable it.

def arg_str_to_bool(arg):
    if arg == "True":
        return True
    elif arg == "False":
        return False
    elif arg == "None" or arg == "":
        return None
    else:
        return arg

# -------------------------
# Virus query
# -------------------------
#@markdown ## **Virus**

virus = "Zaire ebolavirus"  #@param {type:"string"}
#@markdown  - Examples: 'Mammarenavirus lassaense' or 'coronaviridae' or 'NC_045512.2' or '142786' (Norovirus taxid).
virus = arg_str_to_bool(virus)

is_accession = False  #@param {type:"boolean"}
#@markdown  - Check this box if `virus` is given as an NCBI accession (starts with 'NC_').
#@markdown  - For SARS-CoV-2 / Influenza A optimized downloads also check the corresponding box below (see `is_sars_cov2` / `is_alphainfluenza` below)
is_accession = arg_str_to_bool(is_accession)

download_all_accessions = False  #@param {type:"boolean"}
#@markdown  - ⚠️ Downloads ALL virus accessions from NCBI (very large database).
download_all_accessions = arg_str_to_bool(download_all_accessions)

# -------------------------
# Host filters
# -------------------------
#@markdown ## **Host**

host = "Homo sapiens"  #@param {type:"string"}
#@markdown  - Host organism name OR NCBI Taxonomy ID (e.g., 'human', 'Aedes aegypti', '1335626').
#@markdown  - Input 'None' to disable filtering by host.
host = arg_str_to_bool(host)

# -------------------------
# Sequence & gene filters
# -------------------------
#@markdown ## **Sequence & gene filters**
#@markdown NOTE: Do NOT include commas or other characters in number entries (e.g. enter '1900', not '1,900')

annotated = "None"  #@param ["True", "False", "None"]
#@markdown  - True: only annotated sequences. False: only NOT annotated. None: no filter.
annotated = arg_str_to_bool(annotated)

source_database = "None"  #@param ["None", "refseq", "genbank"]
#@markdown  - Limit search to RefSeq (curated) or GenBank genomes only.
source_database = arg_str_to_bool(source_database)

nuc_completeness = "None"  #@param ["None", "complete", "partial"]
#@markdown  - Set to 'complete' to only return nucleotide sequences marked as complete; set to 'partial' to only return sequences that are marked as partial.
nuc_completeness = arg_str_to_bool(nuc_completeness)

min_seq_length = None  #@param {type:"raw"}
max_seq_length = None  #@param {type:"raw"}

min_seq_length = arg_str_to_bool(min_seq_length)
max_seq_length = arg_str_to_bool(max_seq_length)

#@markdown
max_ambiguous_chars = None  #@param {type:"raw"}
#@markdown  - Max number of ambiguous nucleotide characters (N's).
max_ambiguous_chars = arg_str_to_bool(max_ambiguous_chars)

min_gene_count = None  #@param {type:"raw"}
max_gene_count = None  #@param {type:"raw"}
#@markdown
min_gene_count = arg_str_to_bool(min_gene_count)
max_gene_count = arg_str_to_bool(max_gene_count)
#@markdown
min_protein_count = None  #@param {type:"raw"}
max_protein_count = None  #@param {type:"raw"}
#@markdown
min_protein_count = arg_str_to_bool(min_protein_count)
max_protein_count = arg_str_to_bool(max_protein_count)
#@markdown
min_mature_peptide_count = None  #@param {type:"raw"}
max_mature_peptide_count = None  #@param {type:"raw"}
#@markdown
min_mature_peptide_count = arg_str_to_bool(min_mature_peptide_count)
max_mature_peptide_count = arg_str_to_bool(max_mature_peptide_count)

has_proteins = None  #@param {type:"raw"}
#@markdown  - Require specific proteins/genes (e.g. "spike") or list (e.g. ["spike","ORF1ab"]). **Include quotation marks.**
has_proteins = arg_str_to_bool(has_proteins)

proteins_complete = False  #@param {type:"boolean"}
#@markdown  - Only include sequences where all annotated proteins are complete.
proteins_complete = arg_str_to_bool(proteins_complete)

# -------------------------
# Location & submitter filters
# -------------------------
#@markdown ## **Location & submitter filters**

geographic_location = ""  #@param {type:"string"}
#@markdown  - Geographic location of sample collection (e.g. 'USA', 'Asia').
geographic_location = arg_str_to_bool(geographic_location)

submitter_country = ""  #@param {type:"string"}
#@markdown  - Country of the sequence submitter.
submitter_country = arg_str_to_bool(submitter_country)

lab_passaged = "None"  #@param ["True", "False", "None"]
#@markdown  - True: only lab-passaged. False: exclude lab-passaged. None: no filter.
lab_passaged = arg_str_to_bool(lab_passaged)

# -------------------------
# Date filters
# -------------------------
#@markdown ## **Dates**
#@markdown All dates should be supplied in YYYY-MM-DD format.

min_collection_date = "2014-01-01"  #@param {type:"string"}
max_collection_date = "2014-06-30"  #@param {type:"string"}

#@markdown
min_release_date = ""  #@param {type:"string"}
max_release_date = ""  #@param {type:"string"}

min_collection_date = arg_str_to_bool(min_collection_date)
max_collection_date = arg_str_to_bool(max_collection_date)

min_release_date = arg_str_to_bool(min_release_date)
max_release_date = arg_str_to_bool(max_release_date)

# -------------------------
# SARS-CoV-2 specific filters / optimizations
# -------------------------
#@markdown ## **SARS-CoV-2 / Influenza A optimizations**

lineage = ""  #@param {type:"string"}
#@markdown  - SARS-CoV-2 lineage filter (e.g. 'B.1.1.7'). (Only meaningful for SARS-CoV-2 queries.)
lineage = arg_str_to_bool(lineage)

is_sars_cov2 = False  #@param {type:"boolean"}
#@markdown  - Use optimized cached downloads for SARS-CoV-2.
is_sars_cov2 = arg_str_to_bool(is_sars_cov2)

is_alphainfluenza = False  #@param {type:"boolean"}
#@markdown  - Use optimized cached downloads for Influenza A virus (Alphainfluenza).
is_alphainfluenza = arg_str_to_bool(is_alphainfluenza)

# -------------------------
# Optional GenBank metadata enrichment
# -------------------------
#@markdown ## **GenBank metadata enrichment**

genbank_metadata = False  #@param {type:"boolean"}
#@markdown  - Fetch additional detailed metadata from GenBank into a separate CSV/XML/CSV dumps.
genbank_metadata = arg_str_to_bool(genbank_metadata)

genbank_batch_size = 200  #@param {type:"integer"}
#@markdown  - Batch size for GenBank metadata API requests. Larger may be faster but can time out (default: 200).
genbank_batch_size = int(genbank_batch_size)

# -------------------------
# Workflow / output options
# -------------------------
#@markdown ## **Workflow / output options**

keep_temp = False  #@param {type:"boolean"}
#@markdown  - Keep intermediate temporary files.
keep_temp = arg_str_to_bool(keep_temp)

outfolder = "results"  #@param {type:"string"}
#@markdown  - Output folder path.
outfolder = arg_str_to_bool(outfolder)

# %% [markdown]
# # 2. Optional: Upload a fasta file with your own sequences to add to the analysis
#   **1) Click on the folder icon on the left.
#   2) Upload your file to the Google Colab server by dragging in your file (or use rightclick -> Upload).
#   3) Specify the name of your file here:**

# %%
#@title FASTA file containing additional sequences

fasta_file = ""  #@param {type:"string"}
#@markdown  - Example: 'my_fasta_file.fa' or 'my_fasta_file.fasta'.

# %%
#@title Metadata

#@markdown **Option 1: The metadata is the same for all sequences in your FASTA file**
metadata = {'Collection Date': 'YYYY-MM-DD', 'Geo Location': 'South Korea'}  #@param {type:"raw"}
#@markdown - The 'Collection Date' field is required. Optional: you can add as many additional columns as you wish, e.g. 'Geo Location': 'South Korea'.
#@markdown - NOTE: Use NCBI column names where applicable (see https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/virus for example column names)

#@markdown **Option 2: Input a CSV file with metadata for each sequence**
metadata_csv = ""  #@param {type:"string"}
#@markdown  - Example: 'my_metadata.csv'. This file must include at least an 'Accession' and 'Collection Date' column.
#@markdown  - NOTE: Make sure the IDs in the "Accession" column match the IDs of the sequences in the provided FASTA file
#@markdown  - NOTE: Use NCBI column names where applicable (see https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/virus for example column names)

# Convert empty strings to None
fasta_file = arg_str_to_bool(fasta_file)
metadata_csv = arg_str_to_bool(metadata_csv)

# %% [markdown]
# # 3. Optional: Specify Delphy arguments

# %%
#@title Delphy options:
mutation_rate = None  #@param {type:"raw"}
#@markdown  - Virus mutation rate (mutations per site per year), e.g. 0.01. If set to `None`, the mutation rate will be estimated from the generated tree.

delphy_steps = None  #@param {type:"raw"}
#@markdown  - Number of steps to run in the Delphy algorithm (default: 500,000 * number of sequences).

delphy_samples = 200 #@param {type:"integer"}
#@markdown  - Number of logging and tree updates (will log every `delphy_steps/delphy_samples` step).

delphy_release = "1.2.2"  #@param {type:"string"}
#@markdown  - Delphy version to use (see https://github.com/broadinstitute/delphy/releases).

#@title Delphy options:
threads = 2  #@param {type:"integer"}
#@markdown  - Number of threads to use for the MSA (Mafft) and phylogenetic tree (Delphy) generation.

# %% [markdown]
# # Select `Runtime` at the top of this notebook, then click `Run all` and lean back...
# A completion message will be displayed below once the notebook has been successfully executed.
# **💡 Tip: Click on the folder icon 📁 on the left to view/download the files that are being generated.**
#
# <br>
#
# ____
# ____
# ____
# ____

# %%
# %%time

#@title # Generating the phylogenetic tree...

from IPython.display import display, HTML
from pathlib import Path
import subprocess
import sys
import shutil
import glob
import pandas as pd
import re
import os
from datetime import datetime

# ---------- Small UI helpers ----------
def log_message(text):
    display(HTML(f"<h3 style='color:green;margin:6px 0'>{text}</h3>"))

def log_message_sub(text):
    display(HTML(f"<p style='color:black; font-weight:normal; margin:4px 0;'>{text}</p>"))

def log_message_error(text):
    display(HTML(f"<h3 style='color:red;margin:6px 0'>{text}</h3>"))

def run_checked(cmd, **kwargs):
    """Run subprocess.run with sensible defaults and return CompletedProcess or raise."""
    default = dict(check=True, text=True, capture_output=True)
    default.update(kwargs)
    return subprocess.run(cmd, **default)

# ---------- Validate / create outfolder ----------
outfolder = Path(outfolder) if 'outfolder' in globals() else Path("delphy_out")
outfolder.mkdir(parents=True, exist_ok=True)

# ---------- 1) Install Python requirements (gget) ----------
log_message("1/5 Installing Python dependencies (gget)...")
try:
    # !pip install --upgrade -q biopython
    # !pip install -q gget==0.30.5
    import gget
    from Bio import SeqIO
    log_message_sub("Python dependencies installed.")
except Exception as e:
    log_message_error("Failed to install Python dependencies (gget).")
    print(e)
    raise

# ---------- 2) Download sequences from NCBI using gget ----------
log_message("2/5 Downloading viral sequences from NCBI (gget.virus)... This may take a few minutes.")
try:
    # The original code used many parameters assumed present in the notebook; call gget.virus with locals()
    # Build kwargs only from variables that exist in globals() and are not None.
    possible_kwargs = [
        "virus","is_accession","download_all_accessions","host",
        "nuc_completeness","min_seq_length","max_seq_length",
        "min_gene_count","max_gene_count","min_mature_peptide_count","max_mature_peptide_count",
        "min_protein_count","max_protein_count","max_ambiguous_chars","has_proteins","proteins_complete","annotated","source_database",
        "geographic_location","submitter_country","lab_passaged",
        "min_collection_date","max_collection_date","min_release_date","max_release_date",
        "lineage","is_sars_cov2","is_alphainfluenza",
        "genbank_metadata","genbank_batch_size","keep_temp","outfolder"
    ]
    gget_kwargs = {k: globals()[k] for k in possible_kwargs if k in globals() and globals()[k] is not None}
    # Ensure outfolder is string path for gget
    if "outfolder" not in gget_kwargs:
        gget_kwargs["outfolder"] = str(outfolder)
    else:
        gget_kwargs["outfolder"] = str(Path(gget_kwargs["outfolder"]))
    # Call gget.virus
    gget.virus(**gget_kwargs)

    # Find the newest fasta and metadata file in outfolder
    fasta_candidates = list(outfolder.glob("*.fasta")) + list(outfolder.glob("*.fa"))
    if not fasta_candidates:
        raise FileNotFoundError(f"No fasta files were created in {outfolder}")
    ncbi_fasta_file = max(fasta_candidates, key=lambda p: p.stat().st_mtime)

    metadata_candidates = list(outfolder.glob("*.csv")) + list(outfolder.glob("*.jsonl")) + list(outfolder.glob("*.tsv"))
    if not metadata_candidates:
        raise FileNotFoundError(f"No metadata files were created in {outfolder}")
    ncbi_metadata = max(metadata_candidates, key=lambda p: p.stat().st_mtime)

    log_message_sub(f"Download complete. FASTA: {ncbi_fasta_file.name}  Metadata: {ncbi_metadata.name}")
except Exception as e:
    log_message_error("Error while downloading sequences from NCBI.")
    print(e)
    raise

# ---------- 2b) If user provided FASTA/metadata, merge them ----------
input_fasta_file = Path(ncbi_fasta_file)
metadata_file = Path(ncbi_metadata)

if 'fasta_file' in globals() and fasta_file:
    log_message_sub("Merging user-provided FASTA with NCBI FASTA...")
    try:
        combined_fasta_file = outfolder / f"{'_'.join(str(virus).split())}_sequences_combined.fasta"
        with open(combined_fasta_file, "wb") as outfh:
            for src in [ncbi_fasta_file, Path(fasta_file)]:
                with open(src, "rb") as fh:
                    shutil.copyfileobj(fh, outfh)
        input_fasta_file = combined_fasta_file

        # Combine metadata
        combined_metadata_file = outfolder / f"{'_'.join(str(virus).split())}_metadata_combined.csv"
        ncbi_df = pd.read_csv(ncbi_metadata)

        if 'metadata_csv' in globals() and metadata_csv:
            user_meta_df = pd.read_csv(metadata_csv)
            comb_meta_df = pd.concat([ncbi_df, user_meta_df], ignore_index=True, sort=False)
            comb_meta_df.to_csv(combined_metadata_file, index=False)
            metadata_file = combined_metadata_file
        else:
            # If user provided `metadata` mapping and FASTA only
            headers = [record.id.split()[0] for record in SeqIO.parse(fasta_file, "fasta")]
            user_meta_df = pd.DataFrame({"accession": headers})
            if 'metadata' in globals() and isinstance(metadata, dict):
                for k, v in metadata.items():
                    # Broadcast scalar values or accept list-like
                    if hasattr(v, "__len__") and not isinstance(v, str) and len(v) == len(headers):
                        user_meta_df[k] = v
                    else:
                        user_meta_df[k] = [v] * len(headers)
            comb_meta_df = pd.concat([ncbi_df, user_meta_df], ignore_index=True, sort=False)
            comb_meta_df.to_csv(combined_metadata_file, index=False)
            metadata_file = combined_metadata_file

        log_message_sub(f"Merging complete. Combined FASTA: {combined_fasta_file.name}  Combined metadata: {combined_metadata_file.name}")
    except Exception as e:
        log_message_error("Error while merging user-provided data.")
        print(e)
        raise

# ---------- 3) Multiple Sequence Alignment (MSA) using MAFFT (Colab-friendly, --parttree for >10k) ----------
log_message("3/5 Multiple Sequence Alignment (MAFFT). This may take time depending on # sequences and threads.")

aligned_fasta_file = outfolder / f"{'_'.join(str(virus).split())}_aligned.afa"

def count_fasta_records(path: Path):
    return sum(1 for _ in SeqIO.parse(str(path), "fasta"))

# 1) Check for mafft binary
def mafft_is_available():
    return bool(shutil.which("mafft"))

# 2) If not available, attempt the same .deb download + dpkg approach you had for Colab
if not mafft_is_available():
    try:
        log_message_sub("MAFFT not found — attempting to download & install MAFFT .deb (Colab-compatible).")
        deb_path = outfolder / "mafft_7.526-1_amd64.deb"
        # download
        subprocess.run(["wget", "-q", "-O", str(deb_path),
                        "https://mafft.cbrc.jp/alignment/software/mafft_7.526-1_amd64.deb"],
                       check=True, text=True)
        # install
        subprocess.run(["dpkg", "-i", str(deb_path)], check=True, text=True)
        # If dpkg left missing deps, try apt-get -f install
        subprocess.run(["apt-get", "-y", "install", "-f"], check=True, text=True)
        if mafft_is_available():
            log_message_sub("MAFFT installed successfully.")
        else:
            log_message_error("MAFFT was not found after .deb install. Please install MAFFT manually in the Colab environment.")
            raise FileNotFoundError("mafft binary not found after .deb install")
    except subprocess.CalledProcessError as e:
        log_message_error("An error occurred while attempting to install MAFFT via .deb.")
        # print stderr/stdout if available
        try:
            print(e.stderr or e.stdout)
        except Exception:
            print(e)
        raise

# 3) Prepare MAFFT command, adding --parttree for large datasets
num_seqs = count_fasta_records(input_fasta_file)
threads = int(threads) if 'threads' in globals() and threads else 1

# Build command; place --parttree right after "mafft" (recommended)
if num_seqs > 10_000:
    log_message_sub(f"Detected {num_seqs:,} sequences — using MAFFT with --parttree optimized for large datasets.")
    mafft_cmd = ["mafft", "--parttree", "--auto", "--thread", str(threads), str(input_fasta_file)]
else:
    log_message_sub(f"Detected {num_seqs:,} sequences — using MAFFT standard --auto mode.")
    mafft_cmd = ["mafft", "--auto", "--thread", str(threads), str(input_fasta_file)]

# 4) Run MAFFT and write alignment directly to file (no capture_output conflict)
try:
    log_message_sub(f"Running: {' '.join(mafft_cmd[:6])} ... (command truncated in log)")
    with open(aligned_fasta_file, "w") as outfh:
        # IMPORTANT: do NOT use capture_output=True here; provide stdout=outfh instead
        subprocess.run(mafft_cmd, stdout=outfh, stderr=subprocess.PIPE, check=True, text=True)
    log_message_sub(f"MSA complete and saved to: {aligned_fasta_file.name}")
except subprocess.CalledProcessError as e:
    log_message_error("Error while running MAFFT for MSA. See stderr below:")
    stderr = e.stderr.decode() if isinstance(e.stderr, (bytes, bytearray)) else e.stderr
    print(stderr)
    raise
except Exception as e:
    log_message_error("Unexpected error while running MAFFT.")
    print(e)
    raise

# ---------- 4) Reformat FASTA headers to match Delphy format (accession|YYYY-MM-DD) ----------
log_message("4/5 Reformatting FASTA headers to 'accession|YYYY-MM-DD' (skipping entries without valid collection dates).")

def extract_and_format_date(date_string: str, accept_uncertain_dates: bool = False):
    """Return YYYY-MM-DD, YYYY-MM, or YYYY depending on accept_uncertain_dates. Return None if unrecognized."""
    if pd.isna(date_string):
        return None
    date_string = str(date_string).strip()
    # Normalize separators to '-'
    date_string = re.sub(r"[/.]", "-", date_string)
    # Try parsing strict YYYY-MM-DD
    full_date_re = re.compile(r"^\d{4}-\d{1,2}-\d{1,2}$")
    year_month_re = re.compile(r"^\d{4}-\d{1,2}$")
    year_re = re.compile(r"^\d{4}$")
    if full_date_re.match(date_string):
        return date_string
    if year_month_re.match(date_string):
        return date_string if accept_uncertain_dates else "EXCLUDED"
    if year_re.match(date_string):
        return date_string if accept_uncertain_dates else "EXCLUDED"
    # Try to parse more flexible formats (e.g., 'Jan 2 2020' or '2 Jan 2020') using datetime
    for fmt in ("%Y-%m-%d", "%d-%b-%Y", "%d %b %Y", "%b %d %Y", "%Y/%m/%d"):
        try:
            dt = datetime.strptime(date_string, fmt)
            return dt.strftime("%Y-%m-%d")
        except Exception:
            continue
    return None

def find_date_columns(df: pd.DataFrame):
    """Heuristic to find which column likely contains collection date and accession."""
    date_cols = [c for c in df.columns if re.search(r"date|collection|collected", c, flags=re.I)]
    acc_cols = [c for c in df.columns if re.search(r"acc(?:ession)?|id|seq_id", c, flags=re.I)]
    # Fallback sensible names
    if not date_cols and "Collection Date" in df.columns:
        date_cols = ["Collection Date"]
    if not acc_cols and "accession" in df.columns:
        acc_cols = ["accession"]
    # Return first hits or None
    return (date_cols[0] if date_cols else None, acc_cols[0] if acc_cols else None)

def update_fasta_headers(fasta_in: Path, csv_in: Path, fasta_out: Path, accept_uncertain_dates: bool = False):
    """Rewrite fasta headers to 'accession|date' using CSV metadata. Exclude entries without valid date."""
    df = pd.read_csv(csv_in, dtype=str)
    date_col, acc_col = find_date_columns(df)
    if date_col is None or acc_col is None:
        raise ValueError(f"Could not find accession/date columns in {csv_in}. Found columns: {list(df.columns)}")
    accession_to_date = pd.Series(df[date_col].values, index=df[acc_col]).to_dict()

    included = 0
    excluded = 0
    unrecognized = 0

    with open(fasta_in) as fh_in, open(fasta_out, "w") as fh_out:
        for record in SeqIO.parse(fh_in, "fasta"):
            original_accession = record.id.split()[0]
            date_val = accession_to_date.get(original_accession) or accession_to_date.get(original_accession.split("|")[0])
            formatted = extract_and_format_date(date_val, accept_uncertain_dates=accept_uncertain_dates)
            if formatted == "EXCLUDED":
                excluded += 1
                continue
            if formatted is None:
                unrecognized += 1
                continue
            # Set header and remove description
            record.id = f"{original_accession}|{formatted}"
            record.description = ""
            SeqIO.write(record, fh_out, "fasta")
            included += 1

    return {"included": included, "excluded": excluded, "unrecognized": unrecognized}

aligned_fasta_file_clean = outfolder / f"{'_'.join(str(virus).split())}_aligned_headers_adjusted.afa"
try:
    accept_uncertain_dates = bool(globals().get("accept_uncertain_dates", False))
    stats = update_fasta_headers(aligned_fasta_file, metadata_file, aligned_fasta_file_clean, accept_uncertain_dates=accept_uncertain_dates)
    log_message_sub(f"Reformatting complete. Included {stats['included']} sequences; excluded (incomplete dates) {stats['excluded']}; unrecognized {stats['unrecognized']}")
except Exception as e:
    log_message_error("Error while reformatting FASTA headers.")
    print(e)
    raise

# ---------- 5) Run Delphy ----------
log_message("5/5 Preparing and running Delphy. This step can be long depending on steps/samples/sequence count.")

def count_fasta_records(path: Path):
    return sum(1 for _ in SeqIO.parse(str(path), "fasta"))

num_seqs = count_fasta_records(aligned_fasta_file_clean)
if num_seqs == 0:
    raise RuntimeError(f"No sequences found in {aligned_fasta_file_clean}")

# sensible defaults for delphy params if not provided
delphy_steps = globals().get("delphy_steps")
delphy_samples = globals().get("delphy_samples", 100)
if delphy_steps is None:
    delphy_steps = int(500_000 * max(1, num_seqs))

log_every = int(delphy_steps / delphy_samples) if delphy_samples else max(1, delphy_steps // 100)
tree_every = log_every
delphy_snapshot_every = log_every

# Download delphy if not present
delphy_bin = (Path.cwd() / "delphy").resolve()
if not delphy_bin.exists():
    delphy_release = globals().get("delphy_release", "1.2.2")  # user may override
    tarball = outfolder / "delphy_release.tar.gz"
    try:
        download_url = f"https://github.com/broadinstitute/delphy/releases/download/{delphy_release}/delphy-linux-x86_64-ubuntu22.tar.gz"
        log_message_sub(f"Downloading Delphy release {delphy_release}.")
        run_checked(["wget", "-q", "-O", str(tarball), download_url])
        run_checked(["tar", "-xzf", str(tarball)], check=True)
        # Try to find delphy binary in extracted files
        found = list(Path(".").glob("**/delphy"))
        if found:
            src = found[0].resolve()
            dst = delphy_bin.resolve()

            # Make sure the found binary is executable
            src.chmod(src.stat().st_mode | 0o111)

            # Only copy if it's not already the same file
            if src != dst:
                shutil.copy(src, dst)
                dst.chmod(dst.stat().st_mode | 0o111)
                log_message_sub("Delphy binary obtained.")
            else:
                log_message_sub("Delphy binary already present in working directory; skipping copy.")

    except Exception as e:
        log_message_error("Failed to download/extract Delphy. Please ensure `delphy` binary is available in the working directory.")
        print(e)
        raise

# Build Delphy command
beast_log_out = outfolder / f"{'_'.join(str(virus).split())}_delphy_beast.log"
delphy_beast_tree_out = outfolder / f"{'_'.join(str(virus).split())}_delphy_beast.trees"
dphy_out = outfolder / f"{'_'.join(str(virus).split())}_delphy_out.dphy"

mutation_rate = globals().get("mutation_rate", None)
threads = int(globals().get("threads", 1))
cmd = [
    str(delphy_bin),
    "--v0-log-every", str(log_every),
    "--v0-tree-every", str(tree_every),
    "--v0-delphy-snapshot-every", str(delphy_snapshot_every),
    "--v0-threads", str(threads),
    "--v0-steps", str(delphy_steps),
    "--v0-in-fasta", str(aligned_fasta_file_clean),
    "--v0-out-log-file", str(beast_log_out),
    "--v0-out-trees-file", str(delphy_beast_tree_out),
    "--v0-out-delphy-file", str(dphy_out),
]
if mutation_rate:
    cmd = [str(delphy_bin), "--v0-fix-mutation-rate", "--v0-init-mutation-rate", str(mutation_rate)] + cmd[1:]

log_message_sub(f"Running Delphy with command: {' '.join(cmd[:8])} ... (truncated)")

try:
    # Run delphy and stream output to notebook
    proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)
    for line in proc.stdout:
        # print lines incrementally so the notebook shows progress
        print(line, end="")
    ret = proc.wait()
    if ret != 0:
        raise subprocess.CalledProcessError(ret, cmd)

    # Success
    outfolder_display = str(outfolder) if outfolder not in [None, "", "None"] else None

    if outfolder_display:
        location_text = f"Files generated in this notebook are in the left-hand file browser and in the <code>{outfolder_display}/</code> folder."
    else:
        location_text = "Files generated in this notebook are in the left-hand file browser."

    display(HTML(f"""
    <h2 style='color:green'>All done! 🎉</h2>
    <p>{location_text}</p>
    <ul>
      <li>Aligned FASTA: <code>{aligned_fasta_file_clean.name}</code></li>
      <li>Delphy output (.dphy): <code>{dphy_out.name}</code></li>
      <li>Delphy log (.log): <code>{beast_log_out.name}</code></li>
      <li>Delphy trees (.trees): <code>{delphy_beast_tree_out.name}</code></li>
    </ul>
    <p><strong>We recommend downloading the <code>.afa</code>, <code>.dphy</code>, and <code>metadata.csv</code> files.
    To visualize your Delphy output, upload the <code>.dphy</code> (and optionally <code>metadata.csv</code>) file(s) to
    <a href='https://delphy.bio/' target='_blank'>https://delphy.bio/</a>.</strong></p>
    """))

except subprocess.CalledProcessError as e:
    log_message_error("An error occurred while running Delphy. See captured output above for details.")
    print(e)
    raise
except Exception as e:
    log_message_error("Unexpected error while running Delphy.")
    print(e)
    raise
# Out:
# <h3 style='color:green;margin:6px 0'>1/5 Installing Python dependencies (gget)...</h3>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 51.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 75.0 MB/s eta 0:00:00
# <p style='color:black; font-weight:normal; margin:4px 0;'>Python dependencies installed.</p>
# <h3 style='color:green;margin:6px 0'>2/5 Downloading viral sequences from NCBI (gget.virus)... This may take a few minutes.</h3>
# INFO:gget.utils:No NCBI API key provided. Using default rate limit (3 req/sec). Set NCBI_API_KEY env var or pass --api_key for faster requests.
# INFO:gget.utils:Starting virus data retrieval process...
# INFO:gget.utils:Query parameters: virus='Zaire ebolavirus', is_accession=False, outfolder='results'
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 1: VALIDATING INPUT ARGUMENTS AND OUTPUT DIRECTORY SETUP...
# INFO:gget.utils:============================================================
# INFO:gget.utils:Input validation completed successfully
# INFO:gget.utils:Using specified output folder: results
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 2: CHECKING FOR SARS-CoV-2 AND INFLUENZA A QUERIES TO APPLY OPTIMIZED CACHED PATHWAY
# INFO:gget.utils:============================================================
# INFO:gget.utils:No SARS-CoV-2 query detected.
# INFO:gget.utils:No Alphainfluenza query detected.
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 3: Fetching virus metadata from NCBI API
# INFO:gget.utils:============================================================
# INFO:gget.utils:Streaming API metadata to temporary file: results/tmp_20260602_010051_831409/gget_metadata_20260602_010051_831409.jsonl
# INFO:gget.utils:Successfully retrieved 3279 virus records from NCBI API across 4 pages
# INFO:gget.utils:Temporary metadata file size: 10.12 MB
# INFO:gget.utils:📊 MEMORY [after API fetch]: Process RSS=211.3 MB (1.6%), System: 9.9% used, 11695.6 MB available of 12975.5 MB total
# INFO:gget.utils:Loading metadata from streamed temp file (memory-efficient path)...
# INFO:gget.utils:Loading metadata from temp file: results/tmp_20260602_010051_831409/gget_metadata_20260602_010051_831409.jsonl (10.12 MB)
# INFO:gget.utils:Loaded 3279 metadata records from temp file (skipped 0)
# INFO:gget.utils:🗑️ GC [after api_reports conversion]: Collected 0 objects, freed 0.0 MB (246.2 MB -> 246.2 MB)
# INFO:gget.utils:📊 MEMORY [after api_reports cleanup]: Process RSS=246.2 MB (1.9%), System: 10.0% used, 11680.1 MB available of 12975.5 MB total
# INFO:gget.utils:✅ Saved API metadata JSONL: results/Zaire_ebolavirus_api_metadata.jsonl
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 4: Applying metadata-only filters
# INFO:gget.utils:============================================================
# INFO:gget.utils:Starting metadata-only filtering process...
# INFO:gget.utils:Processing 3279 metadata records...
# INFO:gget.utils:✅ Metadata-only filtering process complete.
# INFO:gget.utils:=================================
# INFO:gget.utils:Metadata-only filtering complete:
# INFO:gget.utils:  Total metadata records: 3279
# INFO:gget.utils:  Records passing filters: 277
# INFO:gget.utils:Filter statistics (records excluded):
# INFO:gget.utils:  collection_date: 3002 records
# INFO:gget.utils:📊 MEMORY [after metadata filtering]: Process RSS=246.3 MB (1.9%), System: 10.0% used, 11680.3 MB available of 12975.5 MB total
# INFO:gget.utils:✅ Saved filtered metadata JSONL: results/Zaire_ebolavirus_metadata.jsonl
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 5: Downloading sequences for filtered accessions
# INFO:gget.utils:============================================================
# INFO:gget.utils:Downloading sequences for 277 accessions using E-utilities API
# INFO:gget.utils:Large request detected (277 accessions). Trying EPost+EFetch History Server pipeline...
# INFO:gget.utils:Starting EPost+EFetch pipeline for 277 accessions
# INFO:gget.utils:Uploading 277 accessions to NCBI History Server via EPost...
# INFO:gget.utils:✅ EPost successful: QueryKey=1, WebEnv=MCID_6a1e2b4900bfe2071809939c...
# INFO:gget.utils:Fetching FASTA sequences in batches of 500 (total: 277)
# INFO:gget.utils:✅ EPost+EFetch pipeline complete: 277 sequences downloaded (5.10 MB)
# INFO:gget.utils:Downloaded FASTA file: results/tmp_20260602_010051_831409/virus_sequences_20260602_010051_831409.fasta (5.10 MB)
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 6: Applying sequence-dependent filters and saving results
# INFO:gget.utils:============================================================
# INFO:gget.utils:No sequence-dependent filters specified, skipping this step.
# INFO:gget.utils:Stream-copied 277 FASTA records
# INFO:gget.utils:All 277 downloaded sequences were streamed to output
# INFO:gget.utils:📊 MEMORY [after streaming sequences to output]: Process RSS=255.8 MB (2.0%), System: 10.0% used, 11682.8 MB available of 12975.5 MB total
# INFO:gget.utils:🗑️ GC [after sequence filtering]: Collected 0 objects, freed 0.0 MB (242.0 MB -> 242.0 MB)
# INFO:gget.utils:📊 MEMORY [after sequence filtering cleanup]: Process RSS=242.0 MB (1.9%), System: 10.0% used, 11682.6 MB available of 12975.5 MB total
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 7: Saving final output files
# INFO:gget.utils:============================================================
# INFO:gget.utils:Saving metadata for 277 filtered sequences...
# INFO:gget.utils:✅ FASTA file saved: results/Zaire_ebolavirus_sequences.fasta (5.10 MB)
# INFO:gget.utils:✅ JSONL metadata file saved: results/Zaire_ebolavirus_metadata.jsonl (0.79 MB)
# INFO:gget.utils:Preparing metadata for CSV output...
# INFO:gget.utils:Processing 277 metadata records (chunk_size=50000)...
# INFO:gget.utils:Successfully saved metadata CSV to: results/Zaire_ebolavirus_metadata.csv
# INFO:gget.utils:✅ CSV metadata file saved: results/Zaire_ebolavirus_metadata.csv (0.38 MB)
# INFO:gget.utils:🗑️ GC [before GenBank fetch]: Collected 0 objects, freed 0.0 MB (241.9 MB -> 241.9 MB)
# INFO:gget.utils:============================================================
# INFO:gget.utils:STEP 8: Fetching detailed GenBank metadata
# INFO:gget.utils:============================================================
# INFO:gget.utils:📊 MEMORY [STEP 8 start]: Process RSS=241.9 MB (1.9%), System: 10.0% used, 11684.1 MB available of 12975.5 MB total
# INFO:gget.utils:Skipping this step since GenBank metadata retrieval was not requested.
# INFO:gget.utils:============================================================
# INFO:gget.utils:PROCESS COMPLETED SUCCESSFULLY
# INFO:gget.utils:============================================================
# INFO:gget.utils:Results summary:
# INFO:gget.utils:  Total sequences (API metadata): 3279
# INFO:gget.utils:  After metadata-only filtering: 277
# INFO:gget.utils:  After all filters (final): 277
# INFO:gget.utils:
# INFO:gget.utils:Output files saved to: results
# INFO:gget.utils:  📄 Sequences (FASTA): Zaire_ebolavirus_sequences.fasta
# INFO:gget.utils:  📊 Metadata (CSV):    Zaire_ebolavirus_metadata.csv
# INFO:gget.utils:  🔧 Metadata (JSONL):  Zaire_ebolavirus_metadata.jsonl
# INFO:gget.utils:============================================================
# INFO:gget.utils:============================================================
# INFO:gget.utils:✅ Command summary saved: results/command_summary.txt
# INFO:gget.utils:NCBI virus data retrieval process completed.
# <p style='color:black; font-weight:normal; margin:4px 0;'>Download complete. FASTA: Zaire_ebolavirus_sequences.fasta  Metadata: Zaire_ebolavirus_metadata.csv</p>
# <h3 style='color:green;margin:6px 0'>3/5 Multiple Sequence Alignment (MAFFT). This may take time depending on # sequences and threads.</h3>
# <p style='color:black; font-weight:normal; margin:4px 0;'>MAFFT not found — attempting to download & install MAFFT .deb (Colab-compatible).</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>MAFFT installed successfully.</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Detected 277 sequences — using MAFFT standard --auto mode.</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Running: mafft --auto --thread 2 results/Zaire_ebolavirus_sequences.fasta ... (command truncated in log)</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>MSA complete and saved to: Zaire_ebolavirus_aligned.afa</p>
# <h3 style='color:green;margin:6px 0'>4/5 Reformatting FASTA headers to 'accession|YYYY-MM-DD' (skipping entries without valid collection dates).</h3>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Reformatting complete. Included 277 sequences; excluded (incomplete dates) 0; unrecognized 0</p>
# <h3 style='color:green;margin:6px 0'>5/5 Preparing and running Delphy. This step can be long depending on steps/samples/sequence count.</h3>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Downloading Delphy release 1.2.2.</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Delphy binary already present in working directory; skipping copy.</p>
# <p style='color:black; font-weight:normal; margin:4px 0;'>Running Delphy with command: /content/delphy --v0-log-every 692500 --v0-tree-every 692500 --v0-delphy-snapshot-every 692500 --v0-threads ... (truncated)</p>
# # Seed: 1103288706
# Reading fasta file results/Zaire_ebolavirus_aligned_headers_adjusted.afa
# - read 1 sequences so far (19324 of 5346377 bytes = 0.4%)
# - read 2 sequences so far (38625 of 5346377 bytes = 0.7%)
# - read 3 sequences so far (57926 of 5346377 bytes = 1.1%)
# - read 4 sequences so far (77227 of 5346377 bytes = 1.4%)
# - read 5 sequences so far (96528 of 5346377 bytes = 1.8%)
# - read 6 sequences so far (115829 of 5346377 bytes = 2.2%)
# - read 7 sequences so far (135130 of 5346377 bytes = 2.5%)
# - read 8 sequences so far (154431 of 5346377 bytes = 2.9%)
# - read 9 sequences so far (173732 of 5346377 bytes = 3.2%)
# - read 10 sequences so far (193033 of 5346377 bytes = 3.6%)
# - read 11 sequences so far (212334 of 5346377 bytes = 4.0%)
# - read 12 sequences so far (231635 of 5346377 bytes = 4.3%)
# - read 13 sequences so far (250936 of 5346377 bytes = 4.7%)
# - read 14 sequences so far (270237 of 5346377 bytes = 5.1%)
# - read 15 sequences so far (289538 of 5346377 bytes = 5.4%)
# - read 16 sequences so far (308839 of 5346377 bytes = 5.8%)
# - read 17 sequences so far (328140 of 5346377 bytes = 6.1%)
# - read 18 sequences so far (347441 of 5346377 bytes = 6.5%)
# - read 19 sequences so far (366742 of 5346377 bytes = 6.9%)
# - read 20 sequences so far (386043 of 5346377 bytes = 7.2%)
# - read 21 sequences so far (405344 of 5346377 bytes = 7.6%)
# - read 22 sequences so far (424645 of 5346377 bytes = 7.9%)
# - read 23 sequences so far (443946 of 5346377 bytes = 8.3%)
# - read 24 sequences so far (463247 of 5346377 bytes = 8.7%)
# - read 25 sequences so far (482548 of 5346377 bytes = 9.0%)
# - read 26 sequences so far (501849 of 5346377 bytes = 9.4%)
# - read 27 sequences so far (521150 of 5346377 bytes = 9.7%)
# - read 28 sequences so far (540451 of 5346377 bytes = 10.1%)
# - read 29 sequences so far (559752 of 5346377 bytes = 10.5%)
# - read 30 sequences so far (579053 of 5346377 bytes = 10.8%)
# - read 31 sequences so far (598354 of 5346377 bytes = 11.2%)
# - read 32 sequences so far (617655 of 5346377 bytes = 11.6%)
# - read 33 sequences so far (636956 of 5346377 bytes = 11.9%)
# - read 34 sequences so far (656257 of 5346377 bytes = 12.3%)
# - read 35 sequences so far (675558 of 5346377 bytes = 12.6%)
# - read 36 sequences so far (694859 of 5346377 bytes = 13.0%)
# - read 37 sequences so far (714160 of 5346377 bytes = 13.4%)
# - read 38 sequences so far (733461 of 5346377 bytes = 13.7%)
# - read 39 sequences so far (752762 of 5346377 bytes = 14.1%)
# - read 40 sequences so far (772063 of 5346377 bytes = 14.4%)
# - read 41 sequences so far (791364 of 5346377 bytes = 14.8%)
# - read 42 sequences so far (810665 of 5346377 bytes = 15.2%)
# - read 43 sequences so far (829966 of 5346377 bytes = 15.5%)
# - read 44 sequences so far (849267 of 5346377 bytes = 15.9%)
# - read 45 sequences so far (868568 of 5346377 bytes = 16.2%)
# - read 46 sequences so far (887869 of 5346377 bytes = 16.6%)
# - read 47 sequences so far (907170 of 5346377 bytes = 17.0%)
# - read 48 sequences so far (926471 of 5346377 bytes = 17.3%)
# - read 49 sequences so far (945772 of 5346377 bytes = 17.7%)
# - read 50 sequences so far (965073 of 5346377 bytes = 18.1%)
# - read 51 sequences so far (984374 of 5346377 bytes = 18.4%)
# - read 52 sequences so far (1003675 of 5346377 bytes = 18.8%)
# - read 53 sequences so far (1022976 of 5346377 bytes = 19.1%)
# - read 54 sequences so far (1042277 of 5346377 bytes = 19.5%)
# - read 55 sequences so far (1061578 of 5346377 bytes = 19.9%)
# - read 56 sequences so far (1080879 of 5346377 bytes = 20.2%)
# - read 57 sequences so far (1100180 of 5346377 bytes = 20.6%)
# - read 58 sequences so far (1119481 of 5346377 bytes = 20.9%)
# - read 59 sequences so far (1138782 of 5346377 bytes = 21.3%)
# - read 60 sequences so far (1158083 of 5346377 bytes = 21.7%)
# - read 61 sequences so far (1177384 of 5346377 bytes = 22.0%)
# - read 62 sequences so far (1196685 of 5346377 bytes = 22.4%)
# - read 63 sequences so far (1215986 of 5346377 bytes = 22.7%)
# - read 64 sequences so far (1235287 of 5346377 bytes = 23.1%)
# - read 65 sequences so far (1254588 of 5346377 bytes = 23.5%)
# - read 66 sequences so far (1273889 of 5346377 bytes = 23.8%)
# - read 67 sequences so far (1293190 of 5346377 bytes = 24.2%)
# - read 68 sequences so far (1312491 of 5346377 bytes = 24.5%)
# - read 69 sequences so far (1331792 of 5346377 bytes = 24.9%)
# - read 70 sequences so far (1351093 of 5346377 bytes = 25.3%)
# - read 71 sequences so far (1370394 of 5346377 bytes = 25.6%)
# - read 72 sequences so far (1389695 of 5346377 bytes = 26.0%)
# - read 73 sequences so far (1408996 of 5346377 bytes = 26.4%)
# - read 74 sequences so far (1428297 of 5346377 bytes = 26.7%)
# - read 75 sequences so far (1447598 of 5346377 bytes = 27.1%)
# - read 76 sequences so far (1466899 of 5346377 bytes = 27.4%)
# - read 77 sequences so far (1486200 of 5346377 bytes = 27.8%)
# - read 78 sequences so far (1505501 of 5346377 bytes = 28.2%)
# - read 79 sequences so far (1524802 of 5346377 bytes = 28.5%)
# - read 80 sequences so far (1544103 of 5346377 bytes = 28.9%)
# - read 81 sequences so far (1563404 of 5346377 bytes = 29.2%)
# - read 82 sequences so far (1582705 of 5346377 bytes = 29.6%)
# - read 83 sequences so far (1602006 of 5346377 bytes = 30.0%)
# - read 84 sequences so far (1621307 of 5346377 bytes = 30.3%)
# - read 85 sequences so far (1640608 of 5346377 bytes = 30.7%)
# - read 86 sequences so far (1659909 of 5346377 bytes = 31.0%)
# - read 87 sequences so far (1679210 of 5346377 bytes = 31.4%)
# - read 88 sequences so far (1698511 of 5346377 bytes = 31.8%)
# - read 89 sequences so far (1717812 of 5346377 bytes = 32.1%)
# - read 90 sequences so far (1737113 of 5346377 bytes = 32.5%)
# - read 91 sequences so far (1756414 of 5346377 bytes = 32.9%)
# - read 92 sequences so far (1775715 of 5346377 bytes = 33.2%)
# - read 93 sequences so far (1795016 of 5346377 bytes = 33.6%)
# - read 94 sequences so far (1814317 of 5346377 bytes = 33.9%)
# - read 95 sequences so far (1833618 of 5346377 bytes = 34.3%)
# - read 96 sequences so far (1852919 of 5346377 bytes = 34.7%)
# - read 97 sequences so far (1872220 of 5346377 bytes = 35.0%)
# - read 98 sequences so far (1891521 of 5346377 bytes = 35.4%)
# - read 99 sequences so far (1910822 of 5346377 bytes = 35.7%)
# - read 100 sequences so far (1930123 of 5346377 bytes = 36.1%)
# - read 101 sequences so far (1949424 of 5346377 bytes = 36.5%)
# - read 102 sequences so far (1968725 of 5346377 bytes = 36.8%)
# - read 103 sequences so far (1988026 of 5346377 bytes = 37.2%)
# - read 104 sequences so far (2007327 of 5346377 bytes = 37.5%)
# - read 105 sequences so far (2026628 of 5346377 bytes = 37.9%)
# - read 106 sequences so far (2045929 of 5346377 bytes = 38.3%)
# - read 107 sequences so far (2065230 of 5346377 bytes = 38.6%)
# - read 108 sequences so far (2084531 of 5346377 bytes = 39.0%)
# - read 109 sequences so far (2103832 of 5346377 bytes = 39.4%)
# - read 110 sequences so far (2123133 of 5346377 bytes = 39.7%)
# - read 111 sequences so far (2142434 of 5346377 bytes = 40.1%)
# - read 112 sequences so far (2161735 of 5346377 bytes = 40.4%)
# - read 113 sequences so far (2181036 of 5346377 bytes = 40.8%)
# - read 114 sequences so far (2200337 of 5346377 bytes = 41.2%)
# - read 115 sequences so far (2219638 of 5346377 bytes = 41.5%)
# - read 116 sequences so far (2238939 of 5346377 bytes = 41.9%)
# - read 117 sequences so far (2258240 of 5346377 bytes = 42.2%)
# - read 118 sequences so far (2277541 of 5346377 bytes = 42.6%)
# - read 119 sequences so far (2296842 of 5346377 bytes = 43.0%)
# - read 120 sequences so far (2316143 of 5346377 bytes = 43.3%)
# - read 121 sequences so far (2335444 of 5346377 bytes = 43.7%)
# - read 122 sequences so far (2354745 of 5346377 bytes = 44.0%)
# - read 123 sequences so far (2374046 of 5346377 bytes = 44.4%)
# - read 124 sequences so far (2393347 of 5346377 bytes = 44.8%)
# - read 125 sequences so far (2412648 of 5346377 bytes = 45.1%)
# - read 126 sequences so far (2431949 of 5346377 bytes = 45.5%)
# - read 127 sequences so far (2451250 of 5346377 bytes = 45.8%)
# - read 128 sequences so far (2470551 of 5346377 bytes = 46.2%)
# - read 129 sequences so far (2489852 of 5346377 bytes = 46.6%)
# - read 130 sequences so far (2509153 of 5346377 bytes = 46.9%)
# - read 131 sequences so far (2528454 of 5346377 bytes = 47.3%)
# - read 132 sequences so far (2547755 of 5346377 bytes = 47.7%)
# - read 133 sequences so far (2567056 of 5346377 bytes = 48.0%)
# - read 134 sequences so far (2586357 of 5346377 bytes = 48.4%)
# - read 135 sequences so far (2605658 of 5346377 bytes = 48.7%)
# - read 136 sequences so far (2624959 of 5346377 bytes = 49.1%)
# - read 137 sequences so far (2644260 of 5346377 bytes = 49.5%)
# - read 138 sequences so far (2663561 of 5346377 bytes = 49.8%)
# - read 139 sequences so far (2682862 of 5346377 bytes = 50.2%)
# - read 140 sequences so far (2702163 of 5346377 bytes = 50.5%)
# - read 141 sequences so far (2721464 of 5346377 bytes = 50.9%)
# - read 142 sequences so far (2740765 of 5346377 bytes = 51.3%)
# - read 143 sequences so far (2760066 of 5346377 bytes = 51.6%)
# - read 144 sequences so far (2779367 of 5346377 bytes = 52.0%)
# - read 145 sequences so far (2798668 of 5346377 bytes = 52.3%)
# - read 146 sequences so far (2817969 of 5346377 bytes = 52.7%)
# - read 147 sequences so far (2837270 of 5346377 bytes = 53.1%)
# - read 148 sequences so far (2856571 of 5346377 bytes = 53.4%)
# - read 149 sequences so far (2875872 of 5346377 bytes = 53.8%)
# - read 150 sequences so far (2895173 of 5346377 bytes = 54.2%)
# - read 151 sequences so far (2914474 of 5346377 bytes = 54.5%)
# - read 152 sequences so far (2933775 of 5346377 bytes = 54.9%)
# - read 153 sequences so far (2953076 of 5346377 bytes = 55.2%)
# - read 154 sequences so far (2972377 of 5346377 bytes = 55.6%)
# - read 155 sequences so far (2991678 of 5346377 bytes = 56.0%)
# - read 156 sequences so far (3010979 of 5346377 bytes = 56.3%)
# - read 157 sequences so far (3030280 of 5346377 bytes = 56.7%)
# - read 158 sequences so far (3049581 of 5346377 bytes = 57.0%)
# - read 159 sequences so far (3068882 of 5346377 bytes = 57.4%)
# - read 160 sequences so far (3088183 of 5346377 bytes = 57.8%)
# - read 161 sequences so far (3107484 of 5346377 bytes = 58.1%)
# - read 162 sequences so far (3126785 of 5346377 bytes = 58.5%)
# - read 163 sequences so far (3146086 of 5346377 bytes = 58.8%)
# - read 164 sequences so far (3165387 of 5346377 bytes = 59.2%)
# - read 165 sequences so far (3184688 of 5346377 bytes = 59.6%)
# - read 166 sequences so far (3203989 of 5346377 bytes = 59.9%)
# - read 167 sequences so far (3223290 of 5346377 bytes = 60.3%)
# - read 168 sequences so far (3242591 of 5346377 bytes = 60.7%)
# - read 169 sequences so far (3261892 of 5346377 bytes = 61.0%)
# - read 170 sequences so far (3281193 of 5346377 bytes = 61.4%)
# - read 171 sequences so far (3300494 of 5346377 bytes = 61.7%)
# - read 172 sequences so far (3319795 of 5346377 bytes = 62.1%)
# - read 173 sequences so far (3339096 of 5346377 bytes = 62.5%)
# - read 174 sequences so far (3358397 of 5346377 bytes = 62.8%)
# - read 175 sequences so far (3377698 of 5346377 bytes = 63.2%)
# - read 176 sequences so far (3396999 of 5346377 bytes = 63.5%)
# - read 177 sequences so far (3416300 of 5346377 bytes = 63.9%)
# - read 178 sequences so far (3435601 of 5346377 bytes = 64.3%)
# - read 179 sequences so far (3454902 of 5346377 bytes = 64.6%)
# - read 180 sequences so far (3474203 of 5346377 bytes = 65.0%)
# - read 181 sequences so far (3493504 of 5346377 bytes = 65.3%)
# - read 182 sequences so far (3512805 of 5346377 bytes = 65.7%)
# - read 183 sequences so far (3532106 of 5346377 bytes = 66.1%)
# - read 184 sequences so far (3551407 of 5346377 bytes = 66.4%)
# - read 185 sequences so far (3570708 of 5346377 bytes = 66.8%)
# - read 186 sequences so far (3590009 of 5346377 bytes = 67.1%)
# - read 187 sequences so far (3609310 of 5346377 bytes = 67.5%)
# - read 188 sequences so far (3628611 of 5346377 bytes = 67.9%)
# - read 189 sequences so far (3647912 of 5346377 bytes = 68.2%)
# - read 190 sequences so far (3667213 of 5346377 bytes = 68.6%)
# - read 191 sequences so far (3686514 of 5346377 bytes = 69.0%)
# - read 192 sequences so far (3705815 of 5346377 bytes = 69.3%)
# - read 193 sequences so far (3725116 of 5346377 bytes = 69.7%)
# - read 194 sequences so far (3744417 of 5346377 bytes = 70.0%)
# - read 195 sequences so far (3763718 of 5346377 bytes = 70.4%)
# - read 196 sequences so far (3783019 of 5346377 bytes = 70.8%)
# - read 197 sequences so far (3802320 of 5346377 bytes = 71.1%)
# - read 198 sequences so far (3821621 of 5346377 bytes = 71.5%)
# - read 199 sequences so far (3840922 of 5346377 bytes = 71.8%)
# - read 200 sequences so far (3860223 of 5346377 bytes = 72.2%)
# - read 201 sequences so far (3879524 of 5346377 bytes = 72.6%)
# - read 202 sequences so far (3898825 of 5346377 bytes = 72.9%)
# - read 203 sequences so far (3918126 of 5346377 bytes = 73.3%)
# - read 204 sequences so far (3937427 of 5346377 bytes = 73.6%)
# - read 205 sequences so far (3956728 of 5346377 bytes = 74.0%)
# - read 206 sequences so far (3976029 of 5346377 bytes = 74.4%)
# - read 207 sequences so far (3995330 of 5346377 bytes = 74.7%)
# - read 208 sequences so far (4014631 of 5346377 bytes = 75.1%)
# - read 209 sequences so far (4033932 of 5346377 bytes = 75.5%)
# - read 210 sequences so far (4053233 of 5346377 bytes = 75.8%)
# - read 211 sequences so far (4072534 of 5346377 bytes = 76.2%)
# - read 212 sequences so far (4091835 of 5346377 bytes = 76.5%)
# - read 213 sequences so far (4111136 of 5346377 bytes = 76.9%)
# - read 214 sequences so far (4130437 of 5346377 bytes = 77.3%)
# - read 215 sequences so far (4149738 of 5346377 bytes = 77.6%)
# - read 216 sequences so far (4169039 of 5346377 bytes = 78.0%)
# - read 217 sequences so far (4188340 of 5346377 bytes = 78.3%)
# - read 218 sequences so far (4207641 of 5346377 bytes = 78.7%)
# - read 219 sequences so far (4226942 of 5346377 bytes = 79.1%)
# - read 220 sequences so far (4246243 of 5346377 bytes = 79.4%)
# - read 221 sequences so far (4265544 of 5346377 bytes = 79.8%)
# - read 222 sequences so far (4284845 of 5346377 bytes = 80.1%)
# - read 223 sequences so far (4304146 of 5346377 bytes = 80.5%)
# - read 224 sequences so far (4323447 of 5346377 bytes = 80.9%)
# - read 225 sequences so far (4342748 of 5346377 bytes = 81.2%)
# - read 226 sequences so far (4362049 of 5346377 bytes = 81.6%)
# - read 227 sequences so far (4381350 of 5346377 bytes = 81.9%)
# - read 228 sequences so far (4400651 of 5346377 bytes = 82.3%)
# - read 229 sequences so far (4419952 of 5346377 bytes = 82.7%)
# - read 230 sequences so far (4439253 of 5346377 bytes = 83.0%)
# - read 231 sequences so far (4458554 of 5346377 bytes = 83.4%)
# - read 232 sequences so far (4477855 of 5346377 bytes = 83.8%)
# - read 233 sequences so far (4497156 of 5346377 bytes = 84.1%)
# - read 234 sequences so far (4516457 of 5346377 bytes = 84.5%)
# - read 235 sequences so far (4535758 of 5346377 bytes = 84.8%)
# - read 236 sequences so far (4555059 of 5346377 bytes = 85.2%)
# - read 237 sequences so far (4574360 of 5346377 bytes = 85.6%)
# - read 238 sequences so far (4593661 of 5346377 bytes = 85.9%)
# - read 239 sequences so far (4612962 of 5346377 bytes = 86.3%)
# - read 240 sequences so far (4632263 of 5346377 bytes = 86.6%)
# - read 241 sequences so far (4651564 of 5346377 bytes = 87.0%)
# - read 242 sequences so far (4670865 of 5346377 bytes = 87.4%)
# - read 243 sequences so far (4690166 of 5346377 bytes = 87.7%)
# - read 244 sequences so far (4709467 of 5346377 bytes = 88.1%)
# - read 245 sequences so far (4728768 of 5346377 bytes = 88.4%)
# - read 246 sequences so far (4748069 of 5346377 bytes = 88.8%)
# - read 247 sequences so far (4767370 of 5346377 bytes = 89.2%)
# - read 248 sequences so far (4786671 of 5346377 bytes = 89.5%)
# - read 249 sequences so far (4805972 of 5346377 bytes = 89.9%)
# - read 250 sequences so far (4825273 of 5346377 bytes = 90.3%)
# - read 251 sequences so far (4844574 of 5346377 bytes = 90.6%)
# - read 252 sequences so far (4863875 of 5346377 bytes = 91.0%)
# - read 253 sequences so far (4883176 of 5346377 bytes = 91.3%)
# - read 254 sequences so far (4902477 of 5346377 bytes = 91.7%)
# - read 255 sequences so far (4921778 of 5346377 bytes = 92.1%)
# - read 256 sequences so far (4941079 of 5346377 bytes = 92.4%)
# - read 257 sequences so far (4960380 of 5346377 bytes = 92.8%)
# - read 258 sequences so far (4979681 of 5346377 bytes = 93.1%)
# - read 259 sequences so far (4998982 of 5346377 bytes = 93.5%)
# - read 260 sequences so far (5018283 of 5346377 bytes = 93.9%)
# - read 261 sequences so far (5037584 of 5346377 bytes = 94.2%)
# - read 262 sequences so far (5056885 of 5346377 bytes = 94.6%)
# - read 263 sequences so far (5076186 of 5346377 bytes = 94.9%)
# - read 264 sequences so far (5095487 of 5346377 bytes = 95.3%)
# - read 265 sequences so far (5114788 of 5346377 bytes = 95.7%)
# - read 266 sequences so far (5134089 of 5346377 bytes = 96.0%)
# - read 267 sequences so far (5153390 of 5346377 bytes = 96.4%)
# - read 268 sequences so far (5172691 of 5346377 bytes = 96.8%)
# - read 269 sequences so far (5191992 of 5346377 bytes = 97.1%)
# - read 270 sequences so far (5211293 of 5346377 bytes = 97.5%)
# - read 271 sequences so far (5230594 of 5346377 bytes = 97.8%)
# - read 272 sequences so far (5249895 of 5346377 bytes = 98.2%)
# - read 273 sequences so far (5269196 of 5346377 bytes = 98.6%)
# - read 274 sequences so far (5288497 of 5346377 bytes = 98.9%)
# - read 275 sequences so far (5307798 of 5346377 bytes = 99.3%)
# - read 276 sequences so far (5327099 of 5346377 bytes = 99.6%)
# - read 277 sequences so far (5346377 of 5346377 bytes = 100.0%)
# Analysing fasta file results/Zaire_ebolavirus_aligned_headers_adjusted.afa
# - analysed 0 / 277 sequences
# - analysed 1 / 277 sequences
# - analysed 2 / 277 sequences
# - analysed 3 / 277 sequences
# - analysed 4 / 277 sequences
# - analysed 5 / 277 sequences
# - analysed 6 / 277 sequences
# - analysed 7 / 277 sequences
# - analysed 8 / 277 sequences
# - analysed 9 / 277 sequences
# - analysed 10 / 277 sequences
# - analysed 11 / 277 sequences
# - analysed 12 / 277 sequences
# - analysed 13 / 277 sequences
# - analysed 14 / 277 sequences
# - analysed 15 / 277 sequences
# - analysed 16 / 277 sequences
# - analysed 17 / 277 sequences
# WARNING (sequence 'KU156715.1|2017-12-13'): ambiguous state Y at site 7668 changed to N
# - analysed 18 / 277 sequences
# - analysed 19 / 277 sequences
# - analysed 20 / 277 sequences
# - analysed 21 / 277 sequences
# - analysed 22 / 277 sequences
# - analysed 23 / 277 sequences
# - analysed 24 / 277 sequences
# - analysed 25 / 277 sequences
# - analysed 26 / 277 sequences
# - analysed 27 / 277 sequences
# - analysed 28 / 277 sequences
# - analysed 29 / 277 sequences
# - analysed 30 / 277 sequences
# - analysed 31 / 277 sequences
# - analysed 32 / 277 sequences
# - analysed 33 / 277 sequences
# - analysed 34 / 277 sequences
# - analysed 35 / 277 sequences
# - analysed 36 / 277 sequences
# - analysed 37 / 277 sequences
# - analysed 38 / 277 sequences
# - analysed 39 / 277 sequences
# - analysed 40 / 277 sequences
# - analysed 41 / 277 sequences
# - analysed 42 / 277 sequences
# - analysed 43 / 277 sequences
# - analysed 44 / 277 sequences
# - analysed 45 / 277 sequences
# - analysed 46 / 277 sequences
# - analysed 47 / 277 sequences
# - analysed 48 / 277 sequences
# - analysed 49 / 277 sequences
# - analysed 50 / 277 sequences
# - analysed 51 / 277 sequences
# - analysed 52 / 277 sequences
# - analysed 53 / 277 sequences
# - analysed 54 / 277 sequences
# - analysed 55 / 277 sequences
# - analysed 56 / 277 sequences
# - analysed 57 / 277 sequences
# - analysed 58 / 277 sequences
# - analysed 59 / 277 sequences
# - analysed 60 / 277 sequences
# - analysed 61 / 277 sequences
# - analysed 62 / 277 sequences
# - analysed 63 / 277 sequences
# - analysed 64 / 277 sequences
# - analysed 65 / 277 sequences
# - analysed 66 / 277 sequences
# - analysed 67 / 277 sequences
# - analysed 68 / 277 sequences
# - analysed 69 / 277 sequences
# - analysed 70 / 277 sequences
# - analysed 71 / 277 sequences
# - analysed 72 / 277 sequences
# - analysed 73 / 277 sequences
# - analysed 74 / 277 sequences
# - analysed 75 / 277 sequences
# - analysed 76 / 277 sequences
# - analysed 77 / 277 sequences
# - analysed 78 / 277 sequences
# - analysed 79 / 277 sequences
# - analysed 80 / 277 sequences
# - analysed 81 / 277 sequences
# - analysed 82 / 277 sequences
# - analysed 83 / 277 sequences
# - analysed 84 / 277 sequences
# - analysed 85 / 277 sequences
# - analysed 86 / 277 sequences
# - analysed 87 / 277 sequences
# - analysed 88 / 277 sequences
# - analysed 89 / 277 sequences
# - analysed 90 / 277 sequences
# - analysed 91 / 277 sequences
# - analysed 92 / 277 sequences
# - analysed 93 / 277 sequences
# - analysed 94 / 277 sequences
# - analysed 95 / 277 sequences
# - analysed 96 / 277 sequences
# - analysed 97 / 277 sequences
# - analysed 98 / 277 sequences
# - analysed 99 / 277 sequences
# - analysed 100 / 277 sequences
# - analysed 101 / 277 sequences
# - analysed 102 / 277 sequences
# - analysed 103 / 277 sequences
# - analysed 104 / 277 sequences
# - analysed 105 / 277 sequences
# - analysed 106 / 277 sequences
# - analysed 107 / 277 sequences
# - analysed 108 / 277 sequences
# - analysed 109 / 277 sequences
# - analysed 110 / 277 sequences
# - analysed 111 / 277 sequences
# - analysed 112 / 277 sequences
# - analysed 113 / 277 sequences
# - analysed 114 / 277 sequences
# - analysed 115 / 277 sequences
# - analysed 116 / 277 sequences
# - analysed 117 / 277 sequences
# - analysed 118 / 277 sequences
# - analysed 119 / 277 sequences
# - analysed 120 / 277 sequences
# - analysed 121 / 277 sequences
# - analysed 122 / 277 sequences
# - analysed 123 / 277 sequences
# - analysed 124 / 277 sequences
# - analysed 125 / 277 sequences
# - analysed 126 / 277 sequences
# - analysed 127 / 277 sequences
# - analysed 128 / 277 sequences
# - analysed 129 / 277 sequences
# - analysed 130 / 277 sequences
# - analysed 131 / 277 sequences
# - analysed 132 / 277 sequences
# - analysed 133 / 277 sequences
# - analysed 134 / 277 sequences
# - analysed 135 / 277 sequences
# - analysed 136 / 277 sequences
# - analysed 137 / 277 sequences
# - analysed 138 / 277 sequences
# - analysed 139 / 277 sequences
# - analysed 140 / 277 sequences
# - analysed 141 / 277 sequences
# - analysed 142 / 277 sequences
# - analysed 143 / 277 sequences
# - analysed 144 / 277 sequences
# - analysed 145 / 277 sequences
# - analysed 146 / 277 sequences
# - analysed 147 / 277 sequences
# - analysed 148 / 277 sequences
# - analysed 149 / 277 sequences
# - analysed 150 / 277 sequences
# - analysed 151 / 277 sequences
# - analysed 152 / 277 sequences
# - analysed 153 / 277 sequences
# - analysed 154 / 277 sequences
# - analysed 155 / 277 sequences
# - analysed 156 / 277 sequences
# - analysed 157 / 277 sequences
# - analysed 158 / 277 sequences
# - analysed 159 / 277 sequences
# - analysed 160 / 277 sequences
# - analysed 161 / 277 sequences
# - analysed 162 / 277 sequences
# - analysed 163 / 277 sequences
# - analysed 164 / 277 sequences
# - analysed 165 / 277 sequences
# - analysed 166 / 277 sequences
# - analysed 167 / 277 sequences
# - analysed 168 / 277 sequences
# - analysed 169 / 277 sequences
# - analysed 170 / 277 sequences
# - analysed 171 / 277 sequences
# - analysed 172 / 277 sequences
# WARNING (sequence 'KP096421.1|2014-11-10'): ambiguous state Y at site 9267 changed to N
# - analysed 173 / 277 sequences
# - analysed 174 / 277 sequences
# - analysed 175 / 277 sequences
# - analysed 176 / 277 sequences
# - analysed 177 / 277 sequences
# - analysed 178 / 277 sequences
# - analysed 179 / 277 sequences
# - analysed 180 / 277 sequences
# - analysed 181 / 277 sequences
# - analysed 182 / 277 sequences
# - analysed 183 / 277 sequences
# - analysed 184 / 277 sequences
# - analysed 185 / 277 sequences
# - analysed 186 / 277 sequences
# - analysed 187 / 277 sequences
# - analysed 188 / 277 sequences
# - analysed 189 / 277 sequences
# - analysed 190 / 277 sequences
# - analysed 191 / 277 sequences
# - analysed 192 / 277 sequences
# - analysed 193 / 277 sequences
# - analysed 194 / 277 sequences
# - analysed 195 / 277 sequences
# - analysed 196 / 277 sequences
# - analysed 197 / 277 sequences
# - analysed 198 / 277 sequences
# - analysed 199 / 277 sequences
# - analysed 200 / 277 sequences
# - analysed 201 / 277 sequences
# - analysed 202 / 277 sequences
# - analysed 203 / 277 sequences
# - analysed 204 / 277 sequences
# - analysed 205 / 277 sequences
# - analysed 206 / 277 sequences
# - analysed 207 / 277 sequences
# - analysed 208 / 277 sequences
# - analysed 209 / 277 sequences
# - analysed 210 / 277 sequences
# - analysed 211 / 277 sequences
# - analysed 212 / 277 sequences
# - analysed 213 / 277 sequences
# - analysed 214 / 277 sequences
# - analysed 215 / 277 sequences
# - analysed 216 / 277 sequences
# - analysed 217 / 277 sequences
# - analysed 218 / 277 sequences
# - analysed 219 / 277 sequences
# - analysed 220 / 277 sequences
# - analysed 221 / 277 sequences
# - analysed 222 / 277 sequences
# - analysed 223 / 277 sequences
# - analysed 224 / 277 sequences
# - analysed 225 / 277 sequences
# - analysed 226 / 277 sequences
# - analysed 227 / 277 sequences
# - analysed 228 / 277 sequences
# - analysed 229 / 277 sequences
# - analysed 230 / 277 sequences
# - analysed 231 / 277 sequences
# - analysed 232 / 277 sequences
# - analysed 233 / 277 sequences
# - analysed 234 / 277 sequences
# - analysed 235 / 277 sequences
# - analysed 236 / 277 sequences
# - analysed 237 / 277 sequences
# - analysed 238 / 277 sequences
# - analysed 239 / 277 sequences
# - analysed 240 / 277 sequences
# - analysed 241 / 277 sequences
# - analysed 242 / 277 sequences
# - analysed 243 / 277 sequences
# - analysed 244 / 277 sequences
# - analysed 245 / 277 sequences
# - analysed 246 / 277 sequences
# - analysed 247 / 277 sequences
# - analysed 248 / 277 sequences
# - analysed 249 / 277 sequences
# - analysed 250 / 277 sequences
# - analysed 251 / 277 sequences
# - analysed 252 / 277 sequences
# - analysed 253 / 277 sequences
# - analysed 254 / 277 sequences
# - analysed 255 / 277 sequences
# - analysed 256 / 277 sequences
# - analysed 257 / 277 sequences
# - analysed 258 / 277 sequences
# - analysed 259 / 277 sequences
# - analysed 260 / 277 sequences
# - analysed 261 / 277 sequences
# - analysed 262 / 277 sequences
# - analysed 263 / 277 sequences
# - analysed 264 / 277 sequences
# - analysed 265 / 277 sequences
# - analysed 266 / 277 sequences
# - analysed 267 / 277 sequences
# - analysed 268 / 277 sequences
# - analysed 269 / 277 sequences
# - analysed 270 / 277 sequences
# - analysed 271 / 277 sequences
# - analysed 272 / 277 sequences
# - analysed 273 / 277 sequences
# - analysed 274 / 277 sequences
# - analysed 275 / 277 sequences
# - analysed 276 / 277 sequences
# - analysed 277 / 277 sequences
# Building rough initial tree...
# - added 0 / 277 tips
# - added 2 / 277 tips
# - added 3 / 277 tips
# - added 4 / 277 tips
# - added 5 / 277 tips
# - added 6 / 277 tips
# - added 7 / 277 tips
# - added 8 / 277 tips
# - added 9 / 277 tips
# - added 10 / 277 tips
# - added 11 / 277 tips
# - added 12 / 277 tips
# - added 13 / 277 tips
# - added 14 / 277 tips
# - added 15 / 277 tips
# - added 16 / 277 tips
# - added 17 / 277 tips
# - added 18 / 277 tips
# - added 19 / 277 tips
# - added 20 / 277 tips
# - added 21 / 277 tips
# - added 22 / 277 tips
# - added 23 / 277 tips
# - added 24 / 277 tips
# - added 25 / 277 tips
# - added 26 / 277 tips
# - added 27 / 277 tips
# - added 28 / 277 tips
# - added 29 / 277 tips
# - added 30 / 277 tips
# - added 31 / 277 tips
# - added 32 / 277 tips
# - added 33 / 277 tips
# - added 34 / 277 tips
# - added 35 / 277 tips
# - added 36 / 277 tips
# - added 37 / 277 tips
# - added 38 / 277 tips
# - added 39 / 277 tips
# - added 40 / 277 tips
# - added 41 / 277 tips
# - added 42 / 277 tips
# - added 43 / 277 tips
# - added 44 / 277 tips
# - added 45 / 277 tips
# - added 46 / 277 tips
# - added 47 / 277 tips
# - added 48 / 277 tips
# - added 49 / 277 tips
# - added 50 / 277 tips
# - added 51 / 277 tips
# - added 52 / 277 tips
# - added 53 / 277 tips
# - added 54 / 277 tips
# - added 55 / 277 tips
# - added 56 / 277 tips
# - added 57 / 277 tips
# - added 58 / 277 tips
# - added 59 / 277 tips
# - added 60 / 277 tips
# - added 61 / 277 tips
# - added 62 / 277 tips
# - added 63 / 277 tips
# - added 64 / 277 tips
# - added 65 / 277 tips
# - added 66 / 277 tips
# - added 67 / 277 tips
# - added 68 / 277 tips
# - added 69 / 277 tips
# - added 70 / 277 tips
# - added 71 / 277 tips
# - added 72 / 277 tips
# - added 73 / 277 tips
# - added 74 / 277 tips
# - added 75 / 277 tips
# - added 76 / 277 tips
# - added 77 / 277 tips
# - added 78 / 277 tips
# - added 79 / 277 tips
# - added 80 / 277 tips
# - added 81 / 277 tips
# - added 82 / 277 tips
# - added 83 / 277 tips
# - added 84 / 277 tips
# - added 85 / 277 tips
# - added 86 / 277 tips
# - added 87 / 277 tips
# - added 88 / 277 tips
# - added 89 / 277 tips
# - added 90 / 277 tips
# - added 91 / 277 tips
# - added 92 / 277 tips
# - added 93 / 277 tips
# - added 94 / 277 tips
# - added 95 / 277 tips
# - added 96 / 277 tips
# - added 97 / 277 tips
# - added 98 / 277 tips
# - added 99 / 277 tips
# - added 100 / 277 tips
# - added 101 / 277 tips
# - added 102 / 277 tips
# - added 103 / 277 tips
# - added 104 / 277 tips
# - added 105 / 277 tips
# - added 106 / 277 tips
# - added 107 / 277 tips
# - added 108 / 277 tips
# - added 109 / 277 tips
# - added 110 / 277 tips
# - added 111 / 277 tips
# - added 112 / 277 tips
# - added 113 / 277 tips
# - added 114 / 277 tips
# - added 115 / 277 tips
# - added 116 / 277 tips
# - added 117 / 277 tips
# - added 118 / 277 tips
# - added 119 / 277 tips
# - added 120 / 277 tips
# - added 121 / 277 tips
# - added 122 / 277 tips
# - added 123 / 277 tips
# - added 124 / 277 tips
# - added 125 / 277 tips
# - added 126 / 277 tips
# - added 127 / 277 tips
# - added 128 / 277 tips
# - added 129 / 277 tips
# - added 130 / 277 tips
# - added 131 / 277 tips
# - added 132 / 277 tips
# - added 133 / 277 tips
# - added 134 / 277 tips
# - added 135 / 277 tips
# - added 136 / 277 tips
# - added 137 / 277 tips
# - added 138 / 277 tips
# - added 139 / 277 tips
# - added 140 / 277 tips
# - added 141 / 277 tips
# - added 142 / 277 tips
# - added 143 / 277 tips
# - added 144 / 277 tips
# - added 145 / 277 tips
# - added 146 / 277 tips
# - added 147 / 277 tips
# - added 148 / 277 tips
# - added 149 / 277 tips
# - added 150 / 277 tips
# - added 151 / 277 tips
# - added 152 / 277 tips
# - added 153 / 277 tips
# - added 154 / 277 tips
# - added 155 / 277 tips
# - added 156 / 277 tips
# - added 157 / 277 tips
# - added 158 / 277 tips
# - added 159 / 277 tips
# - added 160 / 277 tips
# - added 161 / 277 tips
# - added 162 / 277 tips
# - added 163 / 277 tips
# - added 164 / 277 tips
# - added 165 / 277 tips
# - added 166 / 277 tips
# - added 167 / 277 tips
# - added 168 / 277 tips
# - added 169 / 277 tips
# - added 170 / 277 tips
# - added 171 / 277 tips
# - added 172 / 277 tips
# - added 173 / 277 tips
# - added 174 / 277 tips
# - added 175 / 277 tips
# - added 176 / 277 tips
# - added 177 / 277 tips
# - added 178 / 277 tips
# - added 179 / 277 tips
# - added 180 / 277 tips
# - added 181 / 277 tips
# - added 182 / 277 tips
# - added 183 / 277 tips
# - added 184 / 277 tips
# - added 185 / 277 tips
# - added 186 / 277 tips
# - added 187 / 277 tips
# - added 188 / 277 tips
# - added 189 / 277 tips
# - added 190 / 277 tips
# - added 191 / 277 tips
# - added 192 / 277 tips
# - added 193 / 277 tips
# - added 194 / 277 tips
# - added 195 / 277 tips
# - added 196 / 277 tips
# - added 197 / 277 tips
# - added 198 / 277 tips
# - added 199 / 277 tips
# - added 200 / 277 tips
# - added 201 / 277 tips
# - added 202 / 277 tips
# - added 203 / 277 tips
# - added 204 / 277 tips
# - added 205 / 277 tips
# - added 206 / 277 tips
# - added 207 / 277 tips
# - added 208 / 277 tips
# - added 209 / 277 tips
# - added 210 / 277 tips
# - added 211 / 277 tips
# - added 212 / 277 tips
# - added 213 / 277 tips
# - added 214 / 277 tips
# - added 215 / 277 tips
# - added 216 / 277 tips
# - added 217 / 277 tips
# - added 218 / 277 tips
# - added 219 / 277 tips
# - added 220 / 277 tips
# - added 221 / 277 tips
# - added 222 / 277 tips
# - added 223 / 277 tips
# - added 224 / 277 tips
# - added 225 / 277 tips
# - added 226 / 277 tips
# - added 227 / 277 tips
# - added 228 / 277 tips
# - added 229 / 277 tips
# - added 230 / 277 tips
# - added 231 / 277 tips
# - added 232 / 277 tips
# - added 233 / 277 tips
# - added 234 / 277 tips
# - added 235 / 277 tips
# - added 236 / 277 tips
# - added 237 / 277 tips
# - added 238 / 277 tips
# - added 239 / 277 tips
# - added 240 / 277 tips
# - added 241 / 277 tips
# - added 242 / 277 tips
# - added 243 / 277 tips
# - added 244 / 277 tips
# - added 245 / 277 tips
# - added 246 / 277 tips
# - added 247 / 277 tips
# - added 248 / 277 tips
# - added 249 / 277 tips
# - added 250 / 277 tips
# - added 251 / 277 tips
# - added 252 / 277 tips
# - added 253 / 277 tips
# - added 254 / 277 tips
# - added 255 / 277 tips
# - added 256 / 277 tips
# - added 257 / 277 tips
# - added 258 / 277 tips
# - added 259 / 277 tips
# - added 260 / 277 tips
# - added 261 / 277 tips
# - added 262 / 277 tips
# - added 263 / 277 tips
# - added 264 / 277 tips
# - added 265 / 277 tips
# - added 266 / 277 tips
# - added 267 / 277 tips
# - added 268 / 277 tips
# - added 269 / 277 tips
# - added 270 / 277 tips
# - added 271 / 277 tips
# - added 272 / 277 tips
# - added 273 / 277 tips
# - added 274 / 277 tips
# - added 275 / 277 tips
# - added 276 / 277 tips
# - added 277 / 277 tips
# Built initial tree with 277 tips
# # Parallelism: 2
# 0.0 M steps/s, Step 0, log_posterior = -67234.61, log_G = -64683.52, log_coal = -6782.13, log_other_priors = 4231.03, num_muts = 1641, T = 306735.22, t_MRCA = 1992-11-04, n0 = 1095.0, g = 0.0000, mu = 1 * 10^-3 subst / site / year, M_ts = 1249, M_tv = 392, kappa = 1, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6054, 4053, 3754, 5099], num_muts_ab counts: [76, 313, 47, 52, 29, 300, 293, 51, 54, 42, 343, 41]
# 0.0 M steps/s, Step 692500, log_posterior = -46812.22, log_G = -48420.55, log_coal = -2619.34, log_other_priors = 4227.67, num_muts = 1416, T = 105545.16, t_MRCA = 1949-04-22, n0 = 5595.1, g = 0.0000, mu = 0.25 * 10^-3 subst / site / year, M_ts = 1079, M_tv = 337, kappa = 6.24, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6055, 4051, 3752, 5102], num_muts_ab counts: [63, 277, 45, 44, 22, 244, 252, 43, 46, 33, 306, 41]
# 0.4 M steps/s, Step 1385000, log_posterior = -46427.95, log_G = -48053.25, log_coal = -2602.29, log_other_priors = 4227.59, num_muts = 1395, T = 101884.05, t_MRCA = 1950-04-28, n0 = 4887.3, g = -0.0000, mu = 0.26 * 10^-3 subst / site / year, M_ts = 1065, M_tv = 330, kappa = 7.15, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6077, 4052, 3734, 5097], num_muts_ab counts: [69, 288, 43, 38, 24, 250, 230, 41, 44, 31, 297, 40]
# 0.3 M steps/s, Step 2077500, log_posterior = -46307.37, log_G = -47894.12, log_coal = -2640.82, log_other_priors = 4227.57, num_muts = 1380, T = 106233.61, t_MRCA = 1950-03-05, n0 = 5874.8, g = 0.0000, mu = 0.25 * 10^-3 subst / site / year, M_ts = 1052, M_tv = 328, kappa = 6.45, pi = [0.31, 0.21, 0.2, 0.28], alpha OFF, nu = 1.000, Root Seq counts: [6077, 4052, 3734, 5097], num_muts_ab counts: [69, 286, 45, 38, 24, 251, 224, 41, 42, 29, 291, 40]
# 0.3 M steps/s, Step 2770000, log_posterior = -46020.64, log_G = -47649.64, log_coal = -2598.90, log_other_priors = 4227.91, num_muts = 1368, T = 101438.25, t_MRCA = 1950-05-01, n0 = 4418.3, g = 0.0000, mu = 0.27 * 10^-3 subst / site / year, M_ts = 1043, M_tv = 325, kappa = 6.22, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6044, 4070, 3751, 5095], num_muts_ab counts: [59, 264, 38, 44, 22, 260, 241, 41, 40, 38, 278, 43]
# 0.3 M steps/s, Step 3462500, log_posterior = -45983.32, log_G = -47579.73, log_coal = -2631.24, log_other_priors = 4227.65, num_muts = 1364, T = 101044.61, t_MRCA = 1954-10-07, n0 = 4843.0, g = 0.0000, mu = 0.26 * 10^-3 subst / site / year, M_ts = 1042, M_tv = 322, kappa = 6.92, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6024, 4060, 3778, 5098], num_muts_ab counts: [63, 237, 39, 40, 22, 253, 267, 41, 42, 35, 285, 40]
# 0.3 M steps/s, Step 4155000, log_posterior = -45951.97, log_G = -47531.57, log_coal = -2647.94, log_other_priors = 4227.54, num_muts = 1357, T = 104809.58, t_MRCA = 1953-10-01, n0 = 5486.0, g = -0.0000, mu = 0.26 * 10^-3 subst / site / year, M_ts = 1035, M_tv = 322, kappa = 6.86, pi = [0.31, 0.22, 0.19, 0.28], alpha OFF, nu = 1.000, Root Seq counts: [6024, 4060, 3778, 5098], num_muts_ab counts: [64, 235, 38, 39, 22, 252, 267, 41, 42, 35, 281, 41]
# 0.3 M steps/s, Step 4847500, log_posterior = -45839.17, log_G = -47446.19, log_coal = -2620.65, log_other_priors = 4227.67, num_muts = 1355, T = 100867.82, t_MRCA = 1953-11-16, n0 = 5041.3, g = 0.0001, mu = 0.26 * 10^-3 subst / site / year, M_ts = 1034, M_tv = 321, kappa = 6.66, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6024, 4060, 3778, 5098], num_muts_ab counts: [64, 236, 38, 39, 22, 250, 266, 41, 42, 35, 282, 40]
# 0.3 M steps/s, Step 5540000, log_posterior = -45823.51, log_G = -47419.12, log_coal = -2631.92, log_other_priors = 4227.53, num_muts = 1351, T = 103366.65, t_MRCA = 1954-02-14, n0 = 5510.8, g = 0.0000, mu = 0.24 * 10^-3 subst / site / year, M_ts = 1032, M_tv = 319, kappa = 6.87, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6024, 4060, 3778, 5098], num_muts_ab counts: [63, 235, 38, 39, 22, 250, 265, 40, 42, 35, 282, 40]
# 0.3 M steps/s, Step 6232500, log_posterior = -45868.90, log_G = -47452.38, log_coal = -2643.99, log_other_priors = 4227.48, num_muts = 1352, T = 105008.35, t_MRCA = 1954-02-23, n0 = 5798.8, g = 0.0000, mu = 0.25 * 10^-3 subst / site / year, M_ts = 1033, M_tv = 319, kappa = 6.88, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6024, 4060, 3778, 5098], num_muts_ab counts: [63, 234, 38, 39, 22, 251, 266, 40, 42, 35, 282, 40]
# 0.3 M steps/s, Step 6925000, log_posterior = -45795.20, log_G = -47393.01, log_coal = -2629.86, log_other_priors = 4227.67, num_muts = 1351, T = 101457.21, t_MRCA = 1954-03-16, n0 = 4731.9, g = -0.0000, mu = 0.26 * 10^-3 subst / site / year, M_ts = 1032, M_tv = 319, kappa = 6.93, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6024, 4060, 3778, 5098], num_muts_ab counts: [63, 234, 39, 38, 22, 250, 266, 40, 41, 36, 282, 40]
# 0.3 M steps/s, Step 7617500, log_posterior = -45928.45, log_G = -47498.89, log_coal = -2657.05, log_other_priors = 4227.49, num_muts = 1355, T = 104759.29, t_MRCA = 1954-06-08, n0 = 5663.2, g = 0.0000, mu = 0.26 * 10^-3 subst / site / year, M_ts = 1034, M_tv = 321, kappa = 6.93, pi = [0.32, 0.21, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4058, 3744, 5096], num_muts_ab counts: [67, 266, 41, 35, 20, 253, 238, 42, 38, 31, 277, 47]
# 0.3 M steps/s, Step 8310000, log_posterior = -45816.22, log_G = -47392.36, log_coal = -2651.52, log_other_priors = 4227.66, num_muts = 1349, T = 103540.14, t_MRCA = 1956-02-14, n0 = 5273.5, g = 0.0000, mu = 0.24 * 10^-3 subst / site / year, M_ts = 1029, M_tv = 320, kappa = 6.53, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6062, 4058, 3744, 5096], num_muts_ab counts: [66, 265, 42, 35, 20, 253, 237, 42, 37, 31, 274, 47]
# ...
# 0.4 M steps/s, Step 116340000, log_posterior = -45999.01, log_G = -47482.74, log_coal = -2743.49, log_other_priors = 4227.21, num_muts = 1328, T = 140721.23, t_MRCA = 1925-08-06, n0 = 8029.8, g = 0.0000, mu = 0.19 * 10^-3 subst / site / year, M_ts = 1016, M_tv = 312, kappa = 6.63, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6061, 4040, 3744, 5115], num_muts_ab counts: [67, 260, 38, 33, 22, 227, 234, 37, 39, 32, 295, 44]
# 0.4 M steps/s, Step 117032500, log_posterior = -45997.77, log_G = -47481.77, log_coal = -2743.59, log_other_priors = 4227.60, num_muts = 1328, T = 140387.07, t_MRCA = 1925-04-16, n0 = 6699.0, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 1015, M_tv = 313, kappa = 5.8, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6061, 4040, 3744, 5115], num_muts_ab counts: [67, 259, 38, 34, 22, 227, 234, 37, 39, 32, 295, 44]
# 0.4 M steps/s, Step 117725000, log_posterior = -45917.61, log_G = -47433.32, log_coal = -2711.64, log_other_priors = 4227.35, num_muts = 1327, T = 137050.51, t_MRCA = 1923-04-21, n0 = 6982.6, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 1014, M_tv = 313, kappa = 6.62, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6061, 4040, 3744, 5115], num_muts_ab counts: [67, 260, 39, 34, 21, 227, 233, 38, 38, 32, 294, 44]
# 0.4 M steps/s, Step 118417500, log_posterior = -45946.33, log_G = -47447.27, log_coal = -2726.34, log_other_priors = 4227.28, num_muts = 1327, T = 138266.15, t_MRCA = 1924-10-16, n0 = 7818.5, g = 0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 1013, M_tv = 314, kappa = 6.45, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6061, 4040, 3744, 5115], num_muts_ab counts: [67, 260, 38, 35, 21, 227, 232, 38, 39, 32, 294, 44]
# 0.4 M steps/s, Step 119110000, log_posterior = -45993.38, log_G = -47473.23, log_coal = -2747.42, log_other_priors = 4227.28, num_muts = 1327, T = 140801.41, t_MRCA = 1924-11-28, n0 = 7387.0, g = -0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 1012, M_tv = 315, kappa = 6.7, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6061, 4040, 3744, 5115], num_muts_ab counts: [67, 259, 38, 35, 22, 227, 232, 38, 39, 32, 294, 44]
# 0.4 M steps/s, Step 119802500, log_posterior = -45975.96, log_G = -47474.80, log_coal = -2728.46, log_other_priors = 4227.30, num_muts = 1326, T = 141747.78, t_MRCA = 1922-07-24, n0 = 7977.8, g = 0.0000, mu = 0.18 * 10^-3 subst / site / year, M_ts = 1008, M_tv = 318, kappa = 6.29, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6044, 4059, 3761, 5096], num_muts_ab counts: [61, 246, 42, 40, 20, 240, 246, 41, 40, 30, 276, 44]
# 0.4 M steps/s, Step 120495000, log_posterior = -45922.58, log_G = -47419.83, log_coal = -2730.07, log_other_priors = 4227.32, num_muts = 1331, T = 128740.40, t_MRCA = 1936-04-24, n0 = 7642.7, g = 0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1013, M_tv = 318, kappa = 6.38, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6065, 4076, 3737, 5082], num_muts_ab counts: [60, 269, 41, 41, 22, 255, 226, 40, 40, 30, 263, 44]
# 0.4 M steps/s, Step 121187500, log_posterior = -45939.69, log_G = -47444.01, log_coal = -2722.99, log_other_priors = 4227.32, num_muts = 1333, T = 128054.29, t_MRCA = 1936-09-11, n0 = 7242.0, g = 0.0000, mu = 0.19 * 10^-3 subst / site / year, M_ts = 1013, M_tv = 320, kappa = 6.61, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6052, 4056, 3747, 5105], num_muts_ab counts: [62, 256, 40, 41, 24, 235, 237, 37, 40, 33, 285, 43]
# 0.4 M steps/s, Step 121880000, log_posterior = -45967.52, log_G = -47470.83, log_coal = -2724.12, log_other_priors = 4227.42, num_muts = 1336, T = 126410.55, t_MRCA = 1939-03-18, n0 = 7462.5, g = 0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1016, M_tv = 320, kappa = 6.06, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6071, 4040, 3743, 5106], num_muts_ab counts: [68, 268, 44, 35, 19, 230, 230, 43, 39, 29, 288, 43]
# 0.4 M steps/s, Step 122572500, log_posterior = -45695.06, log_G = -47244.94, log_coal = -2677.54, log_other_priors = 4227.41, num_muts = 1326, T = 119354.57, t_MRCA = 1939-05-07, n0 = 7261.3, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1009, M_tv = 317, kappa = 6.21, pi = [0.31, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6049, 4060, 3747, 5104], num_muts_ab counts: [57, 259, 37, 44, 22, 236, 232, 39, 42, 34, 282, 42]
# 0.4 M steps/s, Step 123265000, log_posterior = -45890.17, log_G = -47416.73, log_coal = -2701.02, log_other_priors = 4227.57, num_muts = 1334, T = 123618.60, t_MRCA = 1938-04-14, n0 = 6295.6, g = -0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1012, M_tv = 322, kappa = 6.16, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6072, 4051, 3745, 5092], num_muts_ab counts: [69, 268, 43, 36, 21, 239, 226, 40, 46, 29, 279, 38]
# 0.4 M steps/s, Step 123957500, log_posterior = -45918.10, log_G = -47433.20, log_coal = -2712.13, log_other_priors = 4227.22, num_muts = 1332, T = 128016.41, t_MRCA = 1935-07-20, n0 = 7468.6, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1012, M_tv = 320, kappa = 6.9, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6074, 4041, 3737, 5108], num_muts_ab counts: [72, 269, 39, 30, 22, 234, 224, 41, 39, 33, 285, 44]
# 0.4 M steps/s, Step 124650000, log_posterior = -45815.23, log_G = -47351.79, log_coal = -2690.76, log_other_priors = 4227.32, num_muts = 1329, T = 125312.47, t_MRCA = 1935-07-08, n0 = 6358.2, g = 0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1012, M_tv = 317, kappa = 7.16, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6050, 4058, 3758, 5094], num_muts_ab counts: [64, 254, 37, 36, 21, 242, 242, 41, 45, 34, 274, 39]
# 0.4 M steps/s, Step 125342500, log_posterior = -45840.72, log_G = -47390.99, log_coal = -2677.46, log_other_priors = 4227.73, num_muts = 1333, T = 122877.77, t_MRCA = 1934-10-07, n0 = 6138.7, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1014, M_tv = 319, kappa = 5.63, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6058, 4049, 3746, 5107], num_muts_ab counts: [64, 263, 39, 41, 19, 233, 231, 40, 41, 33, 287, 42]
# 0.4 M steps/s, Step 126035000, log_posterior = -45880.94, log_G = -47399.16, log_coal = -2709.34, log_other_priors = 4227.56, num_muts = 1330, T = 127962.74, t_MRCA = 1934-09-04, n0 = 7129.4, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1013, M_tv = 317, kappa = 5.69, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6054, 4049, 3753, 5104], num_muts_ab counts: [61, 257, 39, 42, 20, 232, 233, 39, 46, 32, 291, 38]
# 0.4 M steps/s, Step 126727500, log_posterior = -45832.43, log_G = -47371.88, log_coal = -2688.02, log_other_priors = 4227.47, num_muts = 1331, T = 124761.34, t_MRCA = 1935-03-10, n0 = 6240.5, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1015, M_tv = 316, kappa = 6.62, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6054, 4049, 3753, 5104], num_muts_ab counts: [61, 258, 39, 42, 19, 232, 234, 39, 46, 32, 291, 38]
# 0.4 M steps/s, Step 127420000, log_posterior = -45841.82, log_G = -47375.19, log_coal = -2694.17, log_other_priors = 4227.55, num_muts = 1331, T = 125034.74, t_MRCA = 1935-07-11, n0 = 5745.8, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1015, M_tv = 316, kappa = 6.62, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6054, 4049, 3753, 5104], num_muts_ab counts: [61, 257, 39, 42, 20, 232, 234, 38, 46, 32, 292, 38]
# 0.4 M steps/s, Step 128112500, log_posterior = -45877.52, log_G = -47414.82, log_coal = -2690.17, log_other_priors = 4227.47, num_muts = 1334, T = 124274.56, t_MRCA = 1937-06-09, n0 = 6175.1, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1017, M_tv = 317, kappa = 6.65, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6049, 4042, 3755, 5114], num_muts_ab counts: [64, 250, 39, 37, 18, 231, 244, 42, 37, 31, 292, 49]
# 0.4 M steps/s, Step 128805000, log_posterior = -45848.37, log_G = -47391.28, log_coal = -2684.57, log_other_priors = 4227.48, num_muts = 1335, T = 120854.49, t_MRCA = 1938-07-03, n0 = 5862.7, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1018, M_tv = 317, kappa = 6.82, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6051, 4066, 3746, 5097], num_muts_ab counts: [56, 262, 38, 46, 24, 243, 233, 37, 43, 32, 280, 41]
# 0.4 M steps/s, Step 129497500, log_posterior = -45813.58, log_G = -47376.90, log_coal = -2664.21, log_other_priors = 4227.54, num_muts = 1336, T = 118487.79, t_MRCA = 1939-04-29, n0 = 6031.1, g = 0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 1020, M_tv = 316, kappa = 6.47, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6051, 4066, 3746, 5097], num_muts_ab counts: [56, 263, 38, 46, 23, 243, 234, 37, 43, 32, 280, 41]
# 0.4 M steps/s, Step 130190000, log_posterior = -45811.13, log_G = -47369.10, log_coal = -2669.74, log_other_priors = 4227.71, num_muts = 1335, T = 118756.42, t_MRCA = 1938-06-25, n0 = 5226.0, g = -0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 1020, M_tv = 315, kappa = 6.36, pi = [0.32, 0.22, 0.19, 0.28], alpha OFF, nu = 1.000, Root Seq counts: [6051, 4066, 3746, 5097], num_muts_ab counts: [56, 263, 38, 46, 22, 242, 235, 37, 43, 32, 280, 41]
# 0.3 M steps/s, Step 130882500, log_posterior = -45868.15, log_G = -47397.52, log_coal = -2698.07, log_other_priors = 4227.44, num_muts = 1334, T = 123067.72, t_MRCA = 1937-11-08, n0 = 6107.1, g = -0.0000, mu = 0.22 * 10^-3 subst / site / year, M_ts = 1019, M_tv = 315, kappa = 6.84, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6051, 4066, 3746, 5097], num_muts_ab counts: [56, 262, 38, 45, 23, 242, 235, 37, 43, 32, 280, 41]
# 0.3 M steps/s, Step 131575000, log_posterior = -45910.79, log_G = -47432.91, log_coal = -2705.32, log_other_priors = 4227.43, num_muts = 1335, T = 124647.28, t_MRCA = 1936-12-16, n0 = 7072.4, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1019, M_tv = 316, kappa = 6.23, pi = [0.31, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6051, 4066, 3746, 5097], num_muts_ab counts: [55, 261, 39, 45, 24, 241, 236, 37, 43, 32, 281, 41]
# 0.3 M steps/s, Step 132267500, log_posterior = -45894.28, log_G = -47418.96, log_coal = -2702.89, log_other_priors = 4227.58, num_muts = 1333, T = 125503.34, t_MRCA = 1936-07-04, n0 = 6855.4, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1014, M_tv = 319, kappa = 5.79, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6047, 4078, 3762, 5073], num_muts_ab counts: [60, 248, 43, 41, 20, 261, 244, 40, 45, 29, 261, 41]
# 0.3 M steps/s, Step 132960000, log_posterior = -46041.92, log_G = -47587.39, log_coal = -2682.20, log_other_priors = 4227.68, num_muts = 1342, T = 128367.72, t_MRCA = 1931-03-24, n0 = 5934.4, g = -0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1022, M_tv = 320, kappa = 5.97, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6055, 4041, 3751, 5113], num_muts_ab counts: [62, 260, 38, 38, 21, 230, 233, 41, 44, 36, 299, 40]
# 0.3 M steps/s, Step 133652500, log_posterior = -46004.18, log_G = -47554.28, log_coal = -2677.68, log_other_priors = 4227.77, num_muts = 1341, T = 127035.33, t_MRCA = 1930-06-16, n0 = 6017.0, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1022, M_tv = 319, kappa = 5.54, pi = [0.32, 0.22, 0.19, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6055, 4041, 3751, 5113], num_muts_ab counts: [62, 260, 39, 37, 21, 229, 235, 41, 43, 36, 298, 40]
# 0.3 M steps/s, Step 134345000, log_posterior = -46055.56, log_G = -47575.39, log_coal = -2707.78, log_other_priors = 4227.60, num_muts = 1341, T = 128731.77, t_MRCA = 1932-12-30, n0 = 6051.9, g = 0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1019, M_tv = 322, kappa = 6.2, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6055, 4041, 3751, 5113], num_muts_ab counts: [62, 259, 40, 38, 22, 228, 234, 41, 43, 36, 298, 40]
# 0.3 M steps/s, Step 135037500, log_posterior = -46031.66, log_G = -47565.08, log_coal = -2693.99, log_other_priors = 4227.41, num_muts = 1343, T = 125857.82, t_MRCA = 1933-03-02, n0 = 6300.8, g = 0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1025, M_tv = 318, kappa = 6.83, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6055, 4041, 3751, 5113], num_muts_ab counts: [62, 260, 38, 36, 21, 229, 237, 41, 44, 36, 299, 40]
# 0.3 M steps/s, Step 135730000, log_posterior = -46059.52, log_G = -47577.82, log_coal = -2709.06, log_other_priors = 4227.36, num_muts = 1341, T = 129120.02, t_MRCA = 1933-05-20, n0 = 7951.9, g = 0.0001, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1019, M_tv = 322, kappa = 6.06, pi = [0.32, 0.22, 0.2, 0.26], alpha OFF, nu = 1.000, Root Seq counts: [6055, 4041, 3751, 5113], num_muts_ab counts: [62, 260, 39, 38, 21, 228, 233, 41, 44, 37, 298, 40]
# 0.3 M steps/s, Step 136422500, log_posterior = -45958.85, log_G = -47513.63, log_coal = -2672.81, log_other_priors = 4227.59, num_muts = 1342, T = 121732.48, t_MRCA = 1933-10-03, n0 = 6680.5, g = 0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1020, M_tv = 322, kappa = 5.84, pi = [0.31, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6055, 4041, 3751, 5113], num_muts_ab counts: [62, 259, 39, 38, 22, 229, 234, 41, 44, 36, 298, 40]
# 0.4 M steps/s, Step 137115000, log_posterior = -45848.74, log_G = -47378.15, log_coal = -2697.95, log_other_priors = 4227.36, num_muts = 1330, T = 126261.59, t_MRCA = 1934-01-03, n0 = 6413.5, g = 0.0001, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1012, M_tv = 318, kappa = 6.96, pi = [0.32, 0.22, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6069, 4061, 3738, 5092], num_muts_ab counts: [63, 268, 42, 40, 23, 243, 224, 39, 41, 29, 277, 41]
# 0.4 M steps/s, Step 137807500, log_posterior = -45807.24, log_G = -47347.21, log_coal = -2687.70, log_other_priors = 4227.67, num_muts = 1330, T = 123342.91, t_MRCA = 1936-01-14, n0 = 5201.1, g = -0.0000, mu = 0.21 * 10^-3 subst / site / year, M_ts = 1012, M_tv = 318, kappa = 6.54, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6052, 4059, 3753, 5096], num_muts_ab counts: [66, 252, 39, 35, 21, 246, 242, 41, 37, 33, 272, 46]
# 0.4 M steps/s, Step 138500000, log_posterior = -45796.75, log_G = -47343.54, log_coal = -2680.71, log_other_priors = 4227.50, num_muts = 1330, T = 123192.21, t_MRCA = 1935-08-05, n0 = 6112.2, g = 0.0000, mu = 0.2 * 10^-3 subst / site / year, M_ts = 1013, M_tv = 317, kappa = 6.58, pi = [0.32, 0.21, 0.2, 0.27], alpha OFF, nu = 1.000, Root Seq counts: [6052, 4059, 3753, 5096], num_muts_ab counts: [67, 254, 38, 35, 19, 246, 242, 41, 38, 33, 271, 46]
#     <h2 style='color:green'>All done! 🎉</h2>
#     <p>Files generated in this notebook are in the left-hand file browser and in the <code>results/</code> folder.</p>
#     <ul>
#       <li>Aligned FASTA: <code>Zaire_ebolavirus_aligned_headers_adjusted.afa</code></li>
#       <li>Delphy output (.dphy): <code>Zaire_ebolavirus_delphy_out.dphy</code></li>
#       <li>Delphy log (.log): <code>Zaire_ebolavirus_delphy_beast.log</code></li>
#       <li>Delphy trees (.trees): <code>Zaire_ebolavirus_delphy_beast.trees</code></li>
#     </ul>
#     <p><strong>We recommend downloading the <code>.afa</code>, <code>.dphy</code>, and <code>metadata.csv</code> files.
#     To visualize your Delphy output, upload the <code>.dphy</code> (and optionally <code>metadata.csv</code>) file(s) to
#     <a href='https://delphy.bio/' target='_blank'>https://delphy.bio/</a>.</strong></p>
# CPU times: user 8.62 s, sys: 1.76 s, total: 10.4 s
# Wall time: 8min 19s
